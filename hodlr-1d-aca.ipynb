# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from numpy.linalg import norm
from scipy.spatial.distance import cdist
import time
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2025-11-07 04:00:26.838582: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762488027.233400      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762488027.356220      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def pivoted_aca(A, tol=1e-15, max_rank=None):
    """
    Partially Pivoted ACA (PPACA).
    Approximate A ≈ U V^T without forming the full residual.
    """
    M, N = A.shape
    if max_rank is None:
        max_rank = min(M, N)

    U_list, V_list = [], []
    i = 0
    rows_available = list(range(M))
    cols_available = list(range(N))
    Rnorm_sq = np.sum(A**2)
    Snorm_sq = 0.0
    k = 0

    while k < max_rank and abs((Rnorm_sq - Snorm_sq)) / Rnorm_sq > tol:
        row = A[i, :] - sum(u[i] * v for u, v in zip(U_list, V_list))
        if i in rows_available:
            rows_available.remove(i)

        row_abs = np.abs(row)
        subset = row_abs[cols_available]
        relative_argmax = np.argmax(subset)
        j = cols_available[relative_argmax]

        if np.abs(row[j]) < 1e-14:
            break

        if j in cols_available:
            cols_available.remove(j)

        col = A[:, j] - sum(v[j] * u for u, v in zip(U_list, V_list))
        gamma = 1.0 / row[j]
        u_new = col * gamma
        v_new = row

        Snorm_sq += 2 * sum((u_new @ u) * (v_new @ v) for u, v in zip(U_list, V_list)) + np.linalg.norm(u_new)**2 * np.linalg.norm(v_new)**2

        U_list.append(u_new)
        V_list.append(v_new)

        if not rows_available:
            break

        col_abs = np.abs(col)
        subset = col_abs[rows_available]
        relative_argmax = np.argmax(subset)
        i = rows_available[relative_argmax]
        k += 1

    if not U_list:
        return np.zeros((M,0)), np.zeros((N,0))

    U = np.column_stack(U_list)
    V = np.column_stack(V_list)
    return U, V

# %%
class HODLR_TF:
    def __init__(self, A, tol=1e-6, min_size=32, use_aca=False):
        """
        TensorFlow HODLR decomposition of matrix A.
        If use_aca=True, uses Adaptive Cross Approximation instead of SVD.
        """
        self.n = A.shape[0]
        self.tol = tol
        self.min_size = min_size
        self.use_aca = use_aca
        self.is_leaf = self.n <= min_size

        if self.is_leaf:
            self.A = tf.constant(A, dtype=tf.float32)
            self.U12 = self.V12 = None
            self.U21 = self.V21 = None
            self.A11 = self.A22 = None
        else:
            mid = self.n // 2
            A11, A12 = A[:mid, :mid], A[:mid, mid:]
            A21, A22 = A[mid:, :mid], A[mid:, mid:]

            # Compress off-diagonal blocks
            self.U12, self.V12 = self.low_rank(A12)
            self.U21, self.V21 = self.low_rank(A21)

            # Recurse on diagonal blocks
            self.A11 = HODLR_TF(A11, tol, min_size, use_aca)
            self.A22 = HODLR_TF(A22, tol, min_size, use_aca)

    def low_rank(self, block):
        """
        Low-rank approximation using either SVD (default) or ACA.
        Returns U, V such that block ≈ U @ V.T
        """
        if self.use_aca:
            U, V = pivoted_aca(block, tol=self.tol)
            # Transpose V to keep consistent with SVD-based representation
            return tf.constant(U, dtype=tf.float32), tf.transpose(tf.constant(V, dtype=tf.float32))

        else:
            # Use SVD
            block_tf = tf.constant(block, dtype=tf.float32)
            s, U, V = tf.linalg.svd(block_tf, full_matrices=False)
            mask = s > self.tol
            r = tf.reduce_sum(tf.cast(mask, tf.int32))
            U_r = U[:, :r]
            V_r = V[:, :r]
            S_r = tf.linalg.diag(s[:r])
            return tf.matmul(U_r, S_r), tf.transpose(V_r)
    def matvec(self, x):
        """Multiply HODLR matrix by vector x (TensorFlow ops)"""
        x = tf.convert_to_tensor(x, dtype=tf.float32)

        if self.is_leaf:
            return tf.linalg.matvec(self.A, x)

        mid = self.n // 2
        x1, x2 = x[:mid], x[mid:]

        # Recursively multiply
        y1 = self.A11.matvec(x1)
        y2 = self.A22.matvec(x2)

        # Add low-rank contributions
        if self.U12 is not None:
            y1 += tf.matmul(self.U12, tf.matmul(self.V12, tf.expand_dims(x2, -1)))[:, 0]
        if self.U21 is not None:
            y2 += tf.matmul(self.U21, tf.matmul(self.V21, tf.expand_dims(x1, -1)))[:, 0]

        return tf.concat([y1, y2], axis=0)
        
    def matmat(self, X):
      X = tf.convert_to_tensor(X, dtype=tf.float32)
      if self.is_leaf:
        return tf.matmul(self.A, X)
      mid = self.n // 2
      X1, X2 = X[:mid, :], X[mid:, :]
      Y1 = self.A11.matmat(X1)
      Y2 = self.A22.matmat(X2)
      if self.U12 is not None:
        Y1 += tf.matmul(self.U12, tf.matmul(self.V12, X2))
      if self.U21 is not None:
        Y2 += tf.matmul(self.U21, tf.matmul(self.V21, X1))
      return tf.concat([Y1, Y2], axis=0)

# %%
def benchmark_hodlr_tf(sizes, tol=1e-3, min_size=16):
    times = []
    ranks = []

    for n in sizes:
        x = np.linspace(0, 1, n)
        A = 1.0 / (1.0 + np.abs(x[:, None] - x[None, :]))

        start = time.time()
        hodlr_A = HODLR_TF(A, tol=tol, min_size=min_size,use_aca=True)
        end = time.time()

        # collect ranks iteratively
        stack = [hodlr_A]
        all_ranks = []
        while stack:
            node = stack.pop()
            if not node.is_leaf:
                if node.U12 is not None:
                    all_ranks.append(node.U12.shape[1])
                if node.U21 is not None:
                    all_ranks.append(node.U21.shape[1])
                stack.append(node.A11)
                stack.append(node.A22)

        avg_rank = np.mean(all_ranks) if all_ranks else 0
        times.append(end - start)
        ranks.append(avg_rank)

        print(f"n={n}, time={times[-1]:.3f}s, avg rank={avg_rank:.1f}")

    return times, ranks

# Run benchmarks
sizes = [500, 1000, 1500, 2000, 5000, 10000]
times, ranks = benchmark_hodlr_tf(sizes, tol=1e-3, min_size=16)

# Plotting with log scales
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(np.log10(sizes), times, marker="o")
plt.xlabel("log10(Matrix size n)")
plt.ylabel("Build time (s)")
plt.title("log10(n) vs Build Time")

plt.subplot(1, 2, 2)
plt.plot(np.log10(sizes), ranks, marker="o", color="orange")
plt.xlabel("log10(Matrix size n)")
plt.ylabel("Average rank")
plt.title("log10(n) vs Average Rank")

plt.tight_layout()
plt.show()
# Out:
# I0000 00:00:1762488048.452991      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1762488048.453820      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# n=500, time=1.697s, avg rank=1.5
# n=1000, time=0.099s, avg rank=1.2
# n=1500, time=0.188s, avg rank=1.1
# n=2000, time=0.211s, avg rank=1.1
# n=5000, time=0.808s, avg rank=1.0
# n=10000, time=1.921s, avg rank=1.0

# %%
class GaussianProcessRegression:
    def __init__(self, kernel_fn, noise_level=1e-4):
        self.kernel_fn = kernel_fn
        self.noise_level = noise_level
        self.X_train = None
        self.y_train = None
        self.alpha = None
        self.hodlr_matrix = None
        
    def fit(self, X, y):
        # Convert inputs to float32 for TensorFlow compatibility
        self.X_train = X.astype(np.float32)
        self.y_train = y.astype(np.float32)
        n = len(X)
        
        # Build kernel matrix using HODLR structure
        print(f"Building kernel matrix of size {n}x{n}...")
        K = self.kernel_fn(X, X).astype(np.float32)
        self.hodlr_matrix = HODLR_TF(K, tol=1e-3, min_size=16,use_aca=True)
        
        # Solve (K + σ²I)α = y using conjugate gradient
        print("Solving linear system with conjugate gradient...")
        def matvec(x):
            # Ensure x is converted to TensorFlow tensor
            x_tf = tf.convert_to_tensor(x, dtype=tf.float32)
            return self.hodlr_matrix.matvec(x_tf) + self.noise_level * x_tf
            
        self.alpha = self.conjugate_gradient(matvec, self.y_train)
        print("Training completed!")
        
    def conjugate_gradient(self, A_matvec, b, max_iter=100, tol=1e-6):
        """Conjugate gradient method using HODLR matrix-vector products"""
        # Convert b to TensorFlow tensor
        b = tf.convert_to_tensor(b, dtype=tf.float32)
        n = b.shape[0]
        x = tf.zeros_like(b)
        r = b - A_matvec(x)
        p = r
        rs_old = tf.reduce_sum(r * r)
        
        for i in range(max_iter):
            Ap = A_matvec(p)
            alpha = rs_old / tf.reduce_sum(p * Ap)
            x = x + alpha * p
            r = r - alpha * Ap
            rs_new = tf.reduce_sum(r * r)
            
            if i % 10 == 0:
                print(f"CG iteration {i}, residual: {tf.sqrt(rs_new).numpy():.6f}")
            
            if tf.sqrt(rs_new) < tol:
                print(f"CG converged after {i} iterations")
                break
                
            p = r + (rs_new / rs_old) * p
            rs_old = rs_new
            
        return x.numpy()
        
    def predict(self, X_test):
        print("Making predictions...")
        # Convert test data to float32
        X_test = X_test.astype(np.float32)
        
        # Compute kernel matrices
        K_star = self.kernel_fn(X_test, self.X_train).astype(np.float32)
        K_star_star = self.kernel_fn(X_test, X_test).astype(np.float32)
        
        # Compute predictive mean
        f_mean = K_star @ self.alpha
        
        # Compute predictive variance using conjugate gradient
        # For each test point, we need to solve (K + σ²I) v = k_star
        # Then variance = k_star_star - k_star^T v
        f_var = np.zeros(len(X_test), dtype=np.float32)
        
        # Precompute the diagonal of K_star_star
        k_star_star_diag = np.diag(K_star_star)
        
        # For each test point, solve the linear system
        for i in range(len(X_test)):
            k_star_i = K_star[i:i+1, :].T  # Column vector
            
            # Solve (K + σ²I) v = k_star_i using conjugate gradient
            v = self.conjugate_gradient(
                lambda x: self.hodlr_matrix.matvec(x) + self.noise_level * x,
                k_star_i.flatten()
            )
            
            # Compute variance for this test point
            f_var[i] = k_star_star_diag[i] - k_star_i.T @ v
        
        return f_mean, f_var

# Kernel functions
def cauchy_kernel(X1, X2):
    return 1.0 / (1.0 + cdist(X1, X2, metric='cityblock'))

def rbf_kernel(X1, X2, length_scale=1.0):
    dists = cdist(X1, X2, metric='sqeuclidean')
    return np.exp(-0.5 * dists / (length_scale ** 2))

# %%
# Example usage and testing
# Generate sample data
np.random.seed(42)
n_train = 500
n_test = 100

X_train = np.linspace(0, 10, n_train)[:, None]
y_train = np.sin(X_train).flatten() + 0.1 * np.random.randn(n_train)

X_test = np.linspace(0, 10, n_test)[:, None]

# Fit GPR model
print("Fitting Gaussian Process Regression...")
gpr = GaussianProcessRegression(rbf_kernel, noise_level=0.1)
gpr.fit(X_train, y_train)

# Make predictions
y_mean, y_var = gpr.predict(X_test)

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(X_train, y_train, 'k.', label='Observations', alpha=0.6)
plt.plot(X_test, y_mean, 'b-', label='Predicted mean', linewidth=2)
plt.fill_between(
    X_test.flatten(),
    y_mean - 2 * np.sqrt(y_var),
    y_mean + 2 * np.sqrt(y_var),
    alpha=0.2,
    color='blue',
    label='95% confidence interval'
)
plt.legend()
plt.xlabel('X')
plt.ylabel('y')
plt.title('Gaussian Process Regression with HODLR')
plt.show()
# Out:
# Fitting Gaussian Process Regression...
# Building kernel matrix of size 500x500...
# Solving linear system with conjugate gradient...
# CG iteration 0, residual: 4.415469
# CG iteration 10, residual: 5.445450
# CG iteration 20, residual: 0.520327
# CG iteration 30, residual: 0.231806
# CG iteration 40, residual: 0.080886
# CG iteration 50, residual: 0.016329
# CG iteration 60, residual: 0.004670
# CG iteration 70, residual: 0.001301
# CG iteration 80, residual: 0.001320
# CG iteration 90, residual: 0.001066
# Training completed!
# Making predictions...
# CG iteration 0, residual: 2.920369
# CG iteration 10, residual: 0.304446
# CG iteration 20, residual: 0.065821
# CG iteration 30, residual: 0.013898
# CG iteration 40, residual: 0.017066
# CG iteration 50, residual: 0.002467
# CG iteration 60, residual: 0.001087
# CG iteration 70, residual: 0.000260
# CG iteration 80, residual: 0.000238
# CG iteration 90, residual: 0.000071
# CG iteration 0, residual: 2.910999
# CG iteration 10, residual: 0.209388
# CG iteration 20, residual: 0.049297
# CG iteration 30, residual: 0.013241
# CG iteration 40, residual: 0.011301
# CG iteration 50, residual: 0.002513
# CG iteration 60, residual: 0.000489
# CG iteration 70, residual: 0.000430
# CG iteration 80, residual: 0.000210
# CG iteration 90, residual: 0.000033
# CG iteration 0, residual: 2.875938
# CG iteration 10, residual: 0.114364
# CG iteration 20, residual: 0.035534
# CG iteration 30, residual: 0.009814
# CG iteration 40, residual: 0.007634
# CG iteration 50, residual: 0.001016
# CG iteration 60, residual: 0.000441
# CG iteration 70, residual: 0.000236
# CG iteration 80, residual: 0.000171
# CG iteration 90, residual: 0.000068
# CG iteration 0, residual: 2.817327
# CG iteration 10, residual: 0.042747
# CG iteration 20, residual: 0.031475
# CG iteration 30, residual: 0.006326
# CG iteration 40, residual: 0.004590
# CG iteration 50, residual: 0.001399
# CG iteration 60, residual: 0.000368
# CG iteration 70, residual: 0.000342
# CG iteration 80, residual: 0.000039
# CG iteration 90, residual: 0.000050
# CG iteration 0, residual: 2.738238
# CG iteration 10, residual: 0.025204
# CG iteration 20, residual: 0.031777
# CG iteration 30, residual: 0.007232
# CG iteration 40, residual: 0.003730
# CG iteration 50, residual: 0.001564
# CG iteration 60, residual: 0.000759
# CG iteration 70, residual: 0.000293
# CG iteration 80, residual: 0.000114
# CG iteration 90, residual: 0.000100
# CG iteration 0, residual: 2.642607
# CG iteration 10, residual: 0.050209
# CG iteration 20, residual: 0.028261
# CG iteration 30, residual: 0.006708
# CG iteration 40, residual: 0.007084
# CG iteration 50, residual: 0.002797
# CG iteration 60, residual: 0.001859
# CG iteration 70, residual: 0.000697
# CG iteration 80, residual: 0.000201
# CG iteration 90, residual: 0.000100
# CG iteration 0, residual: 2.535117
# CG iteration 10, residual: 0.039689
# CG iteration 20, residual: 0.013973
# CG iteration 30, residual: 0.006172
# CG iteration 40, residual: 0.002795
# CG iteration 50, residual: 0.003528
# CG iteration 60, residual: 0.001108
# CG iteration 70, residual: 0.000872
# CG iteration 80, residual: 0.000176
# CG iteration 90, residual: 0.000101
# CG iteration 0, residual: 2.421060
# CG iteration 10, residual: 0.058010
# CG iteration 20, residual: 0.019308
# CG iteration 30, residual: 0.006463
# CG iteration 40, residual: 0.002815
# CG iteration 50, residual: 0.002313
# CG iteration 60, residual: 0.001117
# CG iteration 70, residual: 0.000669
# CG iteration 80, residual: 0.000207
# CG iteration 90, residual: 0.000034
# CG iteration 0, residual: 2.306133
# CG iteration 10, residual: 0.048845
# CG iteration 20, residual: 0.026349
# CG iteration 30, residual: 0.021076
# CG iteration 40, residual: 0.006839
# CG iteration 50, residual: 0.001371
# CG iteration 60, residual: 0.000483
# CG iteration 70, residual: 0.000441
# CG iteration 80, residual: 0.000330
# CG iteration 90, residual: 0.000099
# CG iteration 0, residual: 2.196185
# CG iteration 10, residual: 0.068423
# CG iteration 20, residual: 0.015610
# CG iteration 30, residual: 0.019489
# CG iteration 40, residual: 0.001867
# CG iteration 50, residual: 0.000677
# CG iteration 60, residual: 0.000287
# CG iteration 70, residual: 0.000186
# CG iteration 80, residual: 0.000071
# CG iteration 90, residual: 0.000023
# CG iteration 0, residual: 2.096846
# CG iteration 10, residual: 0.066236
# CG iteration 20, residual: 0.020062
# CG iteration 30, residual: 0.010158
# CG iteration 40, residual: 0.001688
# CG iteration 50, residual: 0.001247
# CG iteration 60, residual: 0.000283
# CG iteration 70, residual: 0.000368
# CG iteration 80, residual: 0.000184
# CG iteration 90, residual: 0.000075
# CG iteration 0, residual: 2.013079
# CG iteration 10, residual: 0.066760
# CG iteration 20, residual: 0.033617
# CG iteration 30, residual: 0.013590
# CG iteration 40, residual: 0.005594
# CG iteration 50, residual: 0.003116
# CG iteration 60, residual: 0.000178
# CG iteration 70, residual: 0.000328
# CG iteration 80, residual: 0.000044
# CG iteration 90, residual: 0.000049
# CG iteration 0, residual: 1.948648
# CG iteration 10, residual: 0.068576
# CG iteration 20, residual: 0.036791
# CG iteration 30, residual: 0.009169
# CG iteration 40, residual: 0.004128
# CG iteration 50, residual: 0.001957
# CG iteration 60, residual: 0.000337
# CG iteration 70, residual: 0.000181
# CG iteration 80, residual: 0.000138
# CG iteration 90, residual: 0.000068
# CG iteration 0, residual: 1.905650
# CG iteration 10, residual: 0.051655
# CG iteration 20, residual: 0.025004
# CG iteration 30, residual: 0.005876
# CG iteration 40, residual: 0.003037
# CG iteration 50, residual: 0.001685
# CG iteration 60, residual: 0.000501
# CG iteration 70, residual: 0.000170
# CG iteration 80, residual: 0.000139
# CG iteration 90, residual: 0.000045
# CG iteration 0, residual: 1.884237
# CG iteration 10, residual: 0.054016
# CG iteration 20, residual: 0.023560
# CG iteration 30, residual: 0.005303
# CG iteration 40, residual: 0.000977
# CG iteration 50, residual: 0.001350
# CG iteration 60, residual: 0.000174
# CG iteration 70, residual: 0.000121
# CG iteration 80, residual: 0.000076
# CG iteration 90, residual: 0.000027
# CG iteration 0, residual: 1.882694
# CG iteration 10, residual: 0.084733
# CG iteration 20, residual: 0.022507
# CG iteration 30, residual: 0.004419
# CG iteration 40, residual: 0.003934
# CG iteration 50, residual: 0.001272
# CG iteration 60, residual: 0.000364
# CG iteration 70, residual: 0.000093
# CG iteration 80, residual: 0.000090
# CG iteration 90, residual: 0.000033
# CG iteration 0, residual: 1.897858
# CG iteration 10, residual: 0.129684
# CG iteration 20, residual: 0.015566
# CG iteration 30, residual: 0.002510
# CG iteration 40, residual: 0.001691
# CG iteration 50, residual: 0.000457
# CG iteration 60, residual: 0.000146
# CG iteration 70, residual: 0.000098
# CG iteration 80, residual: 0.000104
# CG iteration 90, residual: 0.000009
# CG iteration 0, residual: 1.925750
# CG iteration 10, residual: 0.071082
# CG iteration 20, residual: 0.022469
# CG iteration 30, residual: 0.003129
# CG iteration 40, residual: 0.007027
# CG iteration 50, residual: 0.000411
# CG iteration 60, residual: 0.000356
# CG iteration 70, residual: 0.000229
# CG iteration 80, residual: 0.000036
# CG iteration 90, residual: 0.000062
# CG iteration 0, residual: 1.962211
# CG iteration 10, residual: 0.040679
# CG iteration 20, residual: 0.019764
# CG iteration 30, residual: 0.004306
# CG iteration 40, residual: 0.001430
# CG iteration 50, residual: 0.000941
# CG iteration 60, residual: 0.000516
# CG iteration 70, residual: 0.000172
# CG iteration 80, residual: 0.000207
# CG iteration 90, residual: 0.000022
# CG iteration 0, residual: 2.003399
# CG iteration 10, residual: 0.047547
# CG iteration 20, residual: 0.016725
# CG iteration 30, residual: 0.010565
# CG iteration 40, residual: 0.002157
# CG iteration 50, residual: 0.000696
# CG iteration 60, residual: 0.000393
# CG iteration 70, residual: 0.000076
# CG iteration 80, residual: 0.000124
# CG iteration 90, residual: 0.000038
# CG iteration 0, residual: 2.046089
# CG iteration 10, residual: 0.067468
# CG iteration 20, residual: 0.007751
# CG iteration 30, residual: 0.005836
# CG iteration 40, residual: 0.002113
# CG iteration 50, residual: 0.001766
# CG iteration 60, residual: 0.000205
# CG iteration 70, residual: 0.000121
# CG iteration 80, residual: 0.000116
# CG iteration 90, residual: 0.000025
# CG iteration 0, residual: 2.087791
# CG iteration 10, residual: 0.052295
# CG iteration 20, residual: 0.017801
# CG iteration 30, residual: 0.009865
# CG iteration 40, residual: 0.003066
# CG iteration 50, residual: 0.001927
# CG iteration 60, residual: 0.000327
# CG iteration 70, residual: 0.000156
# CG iteration 80, residual: 0.000039
# CG iteration 90, residual: 0.000034
# CG iteration 0, residual: 2.126757
# CG iteration 10, residual: 0.037809
# CG iteration 20, residual: 0.043658
# CG iteration 30, residual: 0.007407
# CG iteration 40, residual: 0.002560
# CG iteration 50, residual: 0.000968
# CG iteration 60, residual: 0.000189
# CG iteration 70, residual: 0.000176
# CG iteration 80, residual: 0.000074
# CG iteration 90, residual: 0.000061
# CG iteration 0, residual: 2.161890
# CG iteration 10, residual: 0.052382
# CG iteration 20, residual: 0.044040
# CG iteration 30, residual: 0.006270
# CG iteration 40, residual: 0.002135
# CG iteration 50, residual: 0.002406
# CG iteration 60, residual: 0.001077
# CG iteration 70, residual: 0.000311
# CG iteration 80, residual: 0.000080
# CG iteration 90, residual: 0.000045
# CG iteration 0, residual: 2.192638
# CG iteration 10, residual: 0.054704
# CG iteration 20, residual: 0.034976
# CG iteration 30, residual: 0.010766
# CG iteration 40, residual: 0.006101
# CG iteration 50, residual: 0.001649
# CG iteration 60, residual: 0.000656
# CG iteration 70, residual: 0.000312
# CG iteration 80, residual: 0.000071
# CG iteration 90, residual: 0.000041
# CG iteration 0, residual: 2.218872
# CG iteration 10, residual: 0.064791
# CG iteration 20, residual: 0.025201
# CG iteration 30, residual: 0.006037
# CG iteration 40, residual: 0.002437
# CG iteration 50, residual: 0.002438
# CG iteration 60, residual: 0.000737
# CG iteration 70, residual: 0.000313
# CG iteration 80, residual: 0.000375
# CG iteration 90, residual: 0.000085
# CG iteration 0, residual: 2.240762
# CG iteration 10, residual: 0.077099
# CG iteration 20, residual: 0.009523
# CG iteration 30, residual: 0.007662
# CG iteration 40, residual: 0.004138
# CG iteration 50, residual: 0.002615
# CG iteration 60, residual: 0.000556
# CG iteration 70, residual: 0.000189
# CG iteration 80, residual: 0.000132
# CG iteration 90, residual: 0.000040
# CG iteration 0, residual: 2.258677
# CG iteration 10, residual: 0.076598
# CG iteration 20, residual: 0.021026
# CG iteration 30, residual: 0.010544
# CG iteration 40, residual: 0.004323
# CG iteration 50, residual: 0.003006
# CG iteration 60, residual: 0.000710
# CG iteration 70, residual: 0.000312
# CG iteration 80, residual: 0.000092
# CG iteration 90, residual: 0.000024
# CG iteration 0, residual: 2.273097
# CG iteration 10, residual: 0.071365
# CG iteration 20, residual: 0.024143
# CG iteration 30, residual: 0.004262
# CG iteration 40, residual: 0.002564
# CG iteration 50, residual: 0.000742
# CG iteration 60, residual: 0.000524
# CG iteration 70, residual: 0.000288
# CG iteration 80, residual: 0.000064
# CG iteration 90, residual: 0.000022
# CG iteration 0, residual: 2.284542
# CG iteration 10, residual: 0.054529
# CG iteration 20, residual: 0.043803
# CG iteration 30, residual: 0.011195
# CG iteration 40, residual: 0.004941
# CG iteration 50, residual: 0.003029
# CG iteration 60, residual: 0.000394
# CG iteration 70, residual: 0.000055
# CG iteration 80, residual: 0.000098
# CG iteration 90, residual: 0.000044
# CG iteration 0, residual: 2.293528
# CG iteration 10, residual: 0.036498
# CG iteration 20, residual: 0.045109
# CG iteration 30, residual: 0.006951
# CG iteration 40, residual: 0.003436
# CG iteration 50, residual: 0.003745
# CG iteration 60, residual: 0.000628
# CG iteration 70, residual: 0.000144
# CG iteration 80, residual: 0.000065
# CG iteration 90, residual: 0.000059
# CG iteration 0, residual: 2.300530
# CG iteration 10, residual: 0.046462
# CG iteration 20, residual: 0.020826
# CG iteration 30, residual: 0.005517
# CG iteration 40, residual: 0.002946
# CG iteration 50, residual: 0.001699
# CG iteration 60, residual: 0.000476
# CG iteration 70, residual: 0.000370
# CG iteration 80, residual: 0.000102
# CG iteration 90, residual: 0.000118
# CG iteration 0, residual: 2.305964
# CG iteration 10, residual: 0.037390
# CG iteration 20, residual: 0.033170
# CG iteration 30, residual: 0.009282
# CG iteration 40, residual: 0.002739
# CG iteration 50, residual: 0.001212
# CG iteration 60, residual: 0.000512
# CG iteration 70, residual: 0.000193
# CG iteration 80, residual: 0.000084
# CG iteration 90, residual: 0.000046
# CG iteration 0, residual: 2.310178
# CG iteration 10, residual: 0.048312
# CG iteration 20, residual: 0.026304
# CG iteration 30, residual: 0.008546
# CG iteration 40, residual: 0.001894
# CG iteration 50, residual: 0.001225
# CG iteration 60, residual: 0.000515
# CG iteration 70, residual: 0.000399
# CG iteration 80, residual: 0.000071
# CG iteration 90, residual: 0.000041
# CG iteration 0, residual: 2.313449
# CG iteration 10, residual: 0.053901
# CG iteration 20, residual: 0.033267
# CG iteration 30, residual: 0.007687
# CG iteration 40, residual: 0.001192
# CG iteration 50, residual: 0.000453
# CG iteration 60, residual: 0.000219
# CG iteration 70, residual: 0.000342
# CG iteration 80, residual: 0.000067
# CG iteration 90, residual: 0.000019
# CG iteration 0, residual: 2.315993
# CG iteration 10, residual: 0.041891
# CG iteration 20, residual: 0.015880
# CG iteration 30, residual: 0.004787
# CG iteration 40, residual: 0.002052
# CG iteration 50, residual: 0.000571
# CG iteration 60, residual: 0.000458
# CG iteration 70, residual: 0.000263
# CG iteration 80, residual: 0.000074
# CG iteration 90, residual: 0.000020
# CG iteration 0, residual: 2.317969
# CG iteration 10, residual: 0.040868
# CG iteration 20, residual: 0.027619
# CG iteration 30, residual: 0.002427
# CG iteration 40, residual: 0.002257
# CG iteration 50, residual: 0.001331
# CG iteration 60, residual: 0.000215
# CG iteration 70, residual: 0.000181
# CG iteration 80, residual: 0.000080
# CG iteration 90, residual: 0.000028
# CG iteration 0, residual: 2.319489
# CG iteration 10, residual: 0.071880
# CG iteration 20, residual: 0.032324
# CG iteration 30, residual: 0.005523
# CG iteration 40, residual: 0.003191
# CG iteration 50, residual: 0.001417
# CG iteration 60, residual: 0.000614
# CG iteration 70, residual: 0.000180
# CG iteration 80, residual: 0.000318
# CG iteration 90, residual: 0.000062
# CG iteration 0, residual: 2.320632
# CG iteration 10, residual: 0.084942
# CG iteration 20, residual: 0.010940
# CG iteration 30, residual: 0.005224
# CG iteration 40, residual: 0.004725
# CG iteration 50, residual: 0.001517
# CG iteration 60, residual: 0.000206
# CG iteration 70, residual: 0.000251
# CG iteration 80, residual: 0.000039
# CG iteration 90, residual: 0.000010
# CG iteration 0, residual: 2.321451
# CG iteration 10, residual: 0.083160
# CG iteration 20, residual: 0.033825
# CG iteration 30, residual: 0.003457
# CG iteration 40, residual: 0.002516
# CG iteration 50, residual: 0.001283
# CG iteration 60, residual: 0.000328
# CG iteration 70, residual: 0.000106
# CG iteration 80, residual: 0.000031
# CG iteration 90, residual: 0.000010
# CG iteration 0, residual: 2.321982
# CG iteration 10, residual: 0.075489
# CG iteration 20, residual: 0.012671
# CG iteration 30, residual: 0.007615
# CG iteration 40, residual: 0.001036
# CG iteration 50, residual: 0.000908
# CG iteration 60, residual: 0.000110
# CG iteration 70, residual: 0.000185
# CG iteration 80, residual: 0.000066
# CG iteration 90, residual: 0.000013
# CG iteration 0, residual: 2.322253
# CG iteration 10, residual: 0.061659
# CG iteration 20, residual: 0.007491
# CG iteration 30, residual: 0.004219
# CG iteration 40, residual: 0.001803
# CG iteration 50, residual: 0.000707
# CG iteration 60, residual: 0.000123
# CG iteration 70, residual: 0.000111
# CG iteration 80, residual: 0.000038
# CG iteration 90, residual: 0.000012
# CG iteration 0, residual: 2.322291
# CG iteration 10, residual: 0.045278
# CG iteration 20, residual: 0.010721
# CG iteration 30, residual: 0.004017
# CG iteration 40, residual: 0.003219
# CG iteration 50, residual: 0.000332
# CG iteration 60, residual: 0.000352
# CG iteration 70, residual: 0.000026
# CG iteration 80, residual: 0.000017
# CG iteration 90, residual: 0.000018
# CG iteration 0, residual: 2.322124
# CG iteration 10, residual: 0.028998
# CG iteration 20, residual: 0.008850
# CG iteration 30, residual: 0.001496
# CG iteration 40, residual: 0.001858
# CG iteration 50, residual: 0.001263
# CG iteration 60, residual: 0.000178
# CG iteration 70, residual: 0.000088
# CG iteration 80, residual: 0.000029
# CG iteration 90, residual: 0.000014
# CG iteration 0, residual: 2.321785
# CG iteration 10, residual: 0.033721
# CG iteration 20, residual: 0.014593
# CG iteration 30, residual: 0.002171
# CG iteration 40, residual: 0.003330
# CG iteration 50, residual: 0.000709
# CG iteration 60, residual: 0.000301
# CG iteration 70, residual: 0.000036
# CG iteration 80, residual: 0.000039
# CG iteration 90, residual: 0.000012
# CG iteration 0, residual: 2.321312
# CG iteration 10, residual: 0.054681
# CG iteration 20, residual: 0.013131
# CG iteration 30, residual: 0.004225
# CG iteration 40, residual: 0.003398
# CG iteration 50, residual: 0.000555
# CG iteration 60, residual: 0.000196
# CG iteration 70, residual: 0.000080
# CG iteration 80, residual: 0.000061
# CG iteration 90, residual: 0.000016
# CG iteration 0, residual: 2.320749
# CG iteration 10, residual: 0.086583
# CG iteration 20, residual: 0.028057
# CG iteration 30, residual: 0.005884
# CG iteration 40, residual: 0.004628
# CG iteration 50, residual: 0.001138
# CG iteration 60, residual: 0.000641
# CG iteration 70, residual: 0.000092
# CG iteration 80, residual: 0.000124
# CG iteration 90, residual: 0.000031
# CG iteration 0, residual: 2.320143
# CG iteration 10, residual: 0.111585
# CG iteration 20, residual: 0.014959
# CG iteration 30, residual: 0.006335
# CG iteration 40, residual: 0.003666
# CG iteration 50, residual: 0.001454
# CG iteration 60, residual: 0.000812
# CG iteration 70, residual: 0.000248
# CG iteration 80, residual: 0.000061
# CG iteration 90, residual: 0.000023
# CG iteration 0, residual: 2.319541
# CG iteration 10, residual: 0.096172
# CG iteration 20, residual: 0.012720
# CG iteration 30, residual: 0.003825
# CG iteration 40, residual: 0.002932
# CG iteration 50, residual: 0.001680
# CG iteration 60, residual: 0.000363
# CG iteration 70, residual: 0.000154
# CG iteration 80, residual: 0.000120
# CG iteration 90, residual: 0.000055
# CG iteration 0, residual: 2.318990
# CG iteration 10, residual: 0.066090
# CG iteration 20, residual: 0.015634
# CG iteration 30, residual: 0.002993
# CG iteration 40, residual: 0.002023
# CG iteration 50, residual: 0.001264
# CG iteration 60, residual: 0.000307
# CG iteration 70, residual: 0.000048
# CG iteration 80, residual: 0.000047
# CG iteration 90, residual: 0.000010
# CG iteration 0, residual: 2.318530
# CG iteration 10, residual: 0.049573
# CG iteration 20, residual: 0.015729
# CG iteration 30, residual: 0.005981
# CG iteration 40, residual: 0.000686
# CG iteration 50, residual: 0.001856
# CG iteration 60, residual: 0.000178
# CG iteration 70, residual: 0.000106
# CG iteration 80, residual: 0.000051
# CG iteration 90, residual: 0.000010
# CG iteration 0, residual: 2.318194
# CG iteration 10, residual: 0.083488
# CG iteration 20, residual: 0.025177
# CG iteration 30, residual: 0.007455
# CG iteration 40, residual: 0.001832
# CG iteration 50, residual: 0.002419
# CG iteration 60, residual: 0.000484
# CG iteration 70, residual: 0.000263
# CG iteration 80, residual: 0.000059
# CG iteration 90, residual: 0.000028
# CG iteration 0, residual: 2.318005
# CG iteration 10, residual: 0.074417
# CG iteration 20, residual: 0.033450
# CG iteration 30, residual: 0.006619
# CG iteration 40, residual: 0.005528
# CG iteration 50, residual: 0.002163
# CG iteration 60, residual: 0.001141
# CG iteration 70, residual: 0.000320
# CG iteration 80, residual: 0.000058
# CG iteration 90, residual: 0.000040
# CG iteration 0, residual: 2.317974
# CG iteration 10, residual: 0.059150
# CG iteration 20, residual: 0.040176
# CG iteration 30, residual: 0.007882
# CG iteration 40, residual: 0.005313
# CG iteration 50, residual: 0.002904
# CG iteration 60, residual: 0.000555
# CG iteration 70, residual: 0.000321
# CG iteration 80, residual: 0.000083
# CG iteration 90, residual: 0.000104
# CG iteration 0, residual: 2.318101
# CG iteration 10, residual: 0.043451
# CG iteration 20, residual: 0.024535
# CG iteration 30, residual: 0.005203
# CG iteration 40, residual: 0.003993
# CG iteration 50, residual: 0.000870
# CG iteration 60, residual: 0.000354
# CG iteration 70, residual: 0.000042
# CG iteration 80, residual: 0.000072
# CG iteration 90, residual: 0.000008
# CG iteration 0, residual: 2.318372
# CG iteration 10, residual: 0.030969
# CG iteration 20, residual: 0.021445
# CG iteration 30, residual: 0.011808
# CG iteration 40, residual: 0.005921
# CG iteration 50, residual: 0.001868
# CG iteration 60, residual: 0.000479
# CG iteration 70, residual: 0.000425
# CG iteration 80, residual: 0.000077
# CG iteration 90, residual: 0.000041
# CG iteration 0, residual: 2.318761
# CG iteration 10, residual: 0.030583
# CG iteration 20, residual: 0.020857
# CG iteration 30, residual: 0.007684
# CG iteration 40, residual: 0.001890
# CG iteration 50, residual: 0.003017
# CG iteration 60, residual: 0.000451
# CG iteration 70, residual: 0.000386
# CG iteration 80, residual: 0.000083
# CG iteration 90, residual: 0.000028
# CG iteration 0, residual: 2.319232
# CG iteration 10, residual: 0.049963
# CG iteration 20, residual: 0.025053
# CG iteration 30, residual: 0.007617
# CG iteration 40, residual: 0.004445
# CG iteration 50, residual: 0.001334
# CG iteration 60, residual: 0.000701
# CG iteration 70, residual: 0.000153
# CG iteration 80, residual: 0.000176
# CG iteration 90, residual: 0.000045
# CG iteration 0, residual: 2.319734
# CG iteration 10, residual: 0.066146
# CG iteration 20, residual: 0.021843
# CG iteration 30, residual: 0.005801
# CG iteration 40, residual: 0.002557
# CG iteration 50, residual: 0.002946
# CG iteration 60, residual: 0.000249
# CG iteration 70, residual: 0.000289
# CG iteration 80, residual: 0.000047
# CG iteration 90, residual: 0.000012
# CG iteration 0, residual: 2.320207
# CG iteration 10, residual: 0.083893
# CG iteration 20, residual: 0.034709
# CG iteration 30, residual: 0.008820
# CG iteration 40, residual: 0.002466
# CG iteration 50, residual: 0.001292
# CG iteration 60, residual: 0.000180
# CG iteration 70, residual: 0.000106
# CG iteration 80, residual: 0.000096
# CG iteration 90, residual: 0.000038
# CG iteration 0, residual: 2.320580
# CG iteration 10, residual: 0.090975
# CG iteration 20, residual: 0.024481
# CG iteration 30, residual: 0.006566
# CG iteration 40, residual: 0.002352
# CG iteration 50, residual: 0.002484
# CG iteration 60, residual: 0.000671
# CG iteration 70, residual: 0.000196
# CG iteration 80, residual: 0.000028
# CG iteration 90, residual: 0.000016
# CG iteration 0, residual: 2.320766
# CG iteration 10, residual: 0.089136
# CG iteration 20, residual: 0.014466
# CG iteration 30, residual: 0.007845
# CG iteration 40, residual: 0.005415
# CG iteration 50, residual: 0.000991
# CG iteration 60, residual: 0.000374
# CG iteration 70, residual: 0.000193
# CG iteration 80, residual: 0.000050
# CG iteration 90, residual: 0.000015
# CG iteration 0, residual: 2.320665
# CG iteration 10, residual: 0.077894
# CG iteration 20, residual: 0.024876
# CG iteration 30, residual: 0.009151
# CG iteration 40, residual: 0.002674
# CG iteration 50, residual: 0.000855
# CG iteration 60, residual: 0.000434
# CG iteration 70, residual: 0.000115
# CG iteration 80, residual: 0.000074
# CG iteration 90, residual: 0.000009
# CG iteration 0, residual: 2.320158
# CG iteration 10, residual: 0.048600
# CG iteration 20, residual: 0.012163
# CG iteration 30, residual: 0.007429
# CG iteration 40, residual: 0.003169
# CG iteration 50, residual: 0.001081
# CG iteration 60, residual: 0.000768
# CG iteration 70, residual: 0.000157
# CG iteration 80, residual: 0.000104
# CG iteration 90, residual: 0.000026
# CG iteration 0, residual: 2.319101
# CG iteration 10, residual: 0.040555
# CG iteration 20, residual: 0.016485
# CG iteration 30, residual: 0.003661
# CG iteration 40, residual: 0.002778
# CG iteration 50, residual: 0.000814
# CG iteration 60, residual: 0.000429
# CG iteration 70, residual: 0.000114
# CG iteration 80, residual: 0.000111
# CG iteration 90, residual: 0.000006
# CG iteration 0, residual: 2.317323
# CG iteration 10, residual: 0.055529
# CG iteration 20, residual: 0.024936
# CG iteration 30, residual: 0.003886
# CG iteration 40, residual: 0.000705
# CG iteration 50, residual: 0.000663
# CG iteration 60, residual: 0.000214
# CG iteration 70, residual: 0.000070
# CG iteration 80, residual: 0.000054
# CG iteration 90, residual: 0.000010
# CG iteration 0, residual: 2.314615
# CG iteration 10, residual: 0.049989
# CG iteration 20, residual: 0.021682
# CG iteration 30, residual: 0.001816
# CG iteration 40, residual: 0.002318
# CG iteration 50, residual: 0.000442
# CG iteration 60, residual: 0.000847
# CG iteration 70, residual: 0.000059
# CG iteration 80, residual: 0.000063
# CG iteration 90, residual: 0.000019
# CG iteration 0, residual: 2.310727
# CG iteration 10, residual: 0.039028
# CG iteration 20, residual: 0.026800
# CG iteration 30, residual: 0.002213
# CG iteration 40, residual: 0.002735
# CG iteration 50, residual: 0.000736
# CG iteration 60, residual: 0.000399
# CG iteration 70, residual: 0.000145
# CG iteration 80, residual: 0.000168
# CG iteration 90, residual: 0.000023
# CG iteration 0, residual: 2.305358
# CG iteration 10, residual: 0.063448
# CG iteration 20, residual: 0.018894
# CG iteration 30, residual: 0.002598
# CG iteration 40, residual: 0.003074
# CG iteration 50, residual: 0.000481
# CG iteration 60, residual: 0.000161
# CG iteration 70, residual: 0.000147
# CG iteration 80, residual: 0.000023
# CG iteration 90, residual: 0.000020
# CG iteration 0, residual: 2.298151
# CG iteration 10, residual: 0.038150
# CG iteration 20, residual: 0.032914
# CG iteration 30, residual: 0.005780
# CG iteration 40, residual: 0.002689
# CG iteration 50, residual: 0.001423
# CG iteration 60, residual: 0.000477
# CG iteration 70, residual: 0.000500
# CG iteration 80, residual: 0.000044
# CG iteration 90, residual: 0.000037
# CG iteration 0, residual: 2.288700
# CG iteration 10, residual: 0.055395
# CG iteration 20, residual: 0.028519
# CG iteration 30, residual: 0.006429
# CG iteration 40, residual: 0.004153
# CG iteration 50, residual: 0.000843
# CG iteration 60, residual: 0.000260
# CG iteration 70, residual: 0.000212
# CG iteration 80, residual: 0.000049
# CG iteration 90, residual: 0.000032
# CG iteration 0, residual: 2.276547
# CG iteration 10, residual: 0.072053
# CG iteration 20, residual: 0.027593
# CG iteration 30, residual: 0.003574
# CG iteration 40, residual: 0.002592
# CG iteration 50, residual: 0.000718
# CG iteration 60, residual: 0.000307
# CG iteration 70, residual: 0.000324
# CG iteration 80, residual: 0.000058
# CG iteration 90, residual: 0.000043
# CG iteration 0, residual: 2.261212
# CG iteration 10, residual: 0.079451
# CG iteration 20, residual: 0.016754
# CG iteration 30, residual: 0.004129
# CG iteration 40, residual: 0.002913
# CG iteration 50, residual: 0.001561
# CG iteration 60, residual: 0.000795
# CG iteration 70, residual: 0.000191
# CG iteration 80, residual: 0.000127
# CG iteration 90, residual: 0.000022
# CG iteration 0, residual: 2.242211
# CG iteration 10, residual: 0.080256
# CG iteration 20, residual: 0.012904
# CG iteration 30, residual: 0.006202
# CG iteration 40, residual: 0.003891
# CG iteration 50, residual: 0.000820
# CG iteration 60, residual: 0.000406
# CG iteration 70, residual: 0.000095
# CG iteration 80, residual: 0.000069
# CG iteration 90, residual: 0.000097
# CG iteration 0, residual: 2.219110
# CG iteration 10, residual: 0.070533
# CG iteration 20, residual: 0.013783
# CG iteration 30, residual: 0.004640
# CG iteration 40, residual: 0.003472
# CG iteration 50, residual: 0.000965
# CG iteration 60, residual: 0.000506
# CG iteration 70, residual: 0.000124
# CG iteration 80, residual: 0.000075
# CG iteration 90, residual: 0.000035
# CG iteration 0, residual: 2.191588
# CG iteration 10, residual: 0.076645
# CG iteration 20, residual: 0.033107
# CG iteration 30, residual: 0.005211
# CG iteration 40, residual: 0.006369
# CG iteration 50, residual: 0.001135
# CG iteration 60, residual: 0.000287
# CG iteration 70, residual: 0.000094
# CG iteration 80, residual: 0.000026
# CG iteration 90, residual: 0.000024
# CG iteration 0, residual: 2.159523
# CG iteration 10, residual: 0.091142
# CG iteration 20, residual: 0.023456
# CG iteration 30, residual: 0.006207
# CG iteration 40, residual: 0.000846
# CG iteration 50, residual: 0.002283
# CG iteration 60, residual: 0.000140
# CG iteration 70, residual: 0.000220
# CG iteration 80, residual: 0.000067
# CG iteration 90, residual: 0.000016
# CG iteration 0, residual: 2.123092
# CG iteration 10, residual: 0.040957
# CG iteration 20, residual: 0.020790
# CG iteration 30, residual: 0.005494
# CG iteration 40, residual: 0.000856
# CG iteration 50, residual: 0.001467
# CG iteration 60, residual: 0.000088
# CG iteration 70, residual: 0.000043
# CG iteration 80, residual: 0.000049
# CG iteration 90, residual: 0.000009
# CG iteration 0, residual: 2.082891
# CG iteration 10, residual: 0.032260
# CG iteration 20, residual: 0.005814
# CG iteration 30, residual: 0.006341
# CG iteration 40, residual: 0.001025
# CG iteration 50, residual: 0.001492
# CG iteration 60, residual: 0.000073
# CG iteration 70, residual: 0.000067
# CG iteration 80, residual: 0.000040
# CG iteration 90, residual: 0.000006
# CG iteration 0, residual: 2.040059
# CG iteration 10, residual: 0.053045
# CG iteration 20, residual: 0.028036
# CG iteration 30, residual: 0.006046
# CG iteration 40, residual: 0.002659
# CG iteration 50, residual: 0.000738
# CG iteration 60, residual: 0.000290
# CG iteration 70, residual: 0.000057
# CG iteration 80, residual: 0.000057
# CG iteration 90, residual: 0.000021
# CG iteration 0, residual: 1.996386
# CG iteration 10, residual: 0.050463
# CG iteration 20, residual: 0.030435
# CG iteration 30, residual: 0.003825
# CG iteration 40, residual: 0.001277
# CG iteration 50, residual: 0.000541
# CG iteration 60, residual: 0.000325
# CG iteration 70, residual: 0.000082
# CG iteration 80, residual: 0.000118
# CG iteration 90, residual: 0.000019
# CG iteration 0, residual: 1.954397
# CG iteration 10, residual: 0.058831
# CG iteration 20, residual: 0.018159
# CG iteration 30, residual: 0.002063
# CG iteration 40, residual: 0.002314
# CG iteration 50, residual: 0.000420
# CG iteration 60, residual: 0.000459
# CG iteration 70, residual: 0.000204
# CG iteration 80, residual: 0.000025
# CG iteration 90, residual: 0.000008
# CG iteration 0, residual: 1.917355
# CG iteration 10, residual: 0.086051
# CG iteration 20, residual: 0.020581
# CG iteration 30, residual: 0.002032
# CG iteration 40, residual: 0.003380
# CG iteration 50, residual: 0.000585
# CG iteration 60, residual: 0.000162
# CG iteration 70, residual: 0.000091
# CG iteration 80, residual: 0.000027
# CG iteration 90, residual: 0.000021
# CG iteration 0, residual: 1.889129
# CG iteration 10, residual: 0.099395
# CG iteration 20, residual: 0.019170
# CG iteration 30, residual: 0.001736
# CG iteration 40, residual: 0.001495
# CG iteration 50, residual: 0.000724
# CG iteration 60, residual: 0.000290
# CG iteration 70, residual: 0.000078
# CG iteration 80, residual: 0.000030
# CG iteration 90, residual: 0.000033
# CG iteration 0, residual: 1.873902
# CG iteration 10, residual: 0.066647
# CG iteration 20, residual: 0.026851
# CG iteration 30, residual: 0.003841
# CG iteration 40, residual: 0.001624
# CG iteration 50, residual: 0.000413
# CG iteration 60, residual: 0.000286
# CG iteration 70, residual: 0.000070
# CG iteration 80, residual: 0.000033
# CG iteration 90, residual: 0.000038
# CG iteration 0, residual: 1.875654
# CG iteration 10, residual: 0.048503
# CG iteration 20, residual: 0.024900
# CG iteration 30, residual: 0.003092
# CG iteration 40, residual: 0.002344
# CG iteration 50, residual: 0.000382
# CG iteration 60, residual: 0.000164
# CG iteration 70, residual: 0.000071
# CG iteration 80, residual: 0.000111
# CG iteration 90, residual: 0.000027
# CG iteration 0, residual: 1.897525
# CG iteration 10, residual: 0.046879
# CG iteration 20, residual: 0.021167
# CG iteration 30, residual: 0.001944
# CG iteration 40, residual: 0.001096
# CG iteration 50, residual: 0.000543
# CG iteration 60, residual: 0.000233
# CG iteration 70, residual: 0.000109
# CG iteration 80, residual: 0.000049
# CG iteration 90, residual: 0.000004
# CG iteration 0, residual: 1.941186
# CG iteration 10, residual: 0.059456
# CG iteration 20, residual: 0.033097
# CG iteration 30, residual: 0.004285
# CG iteration 40, residual: 0.002047
# CG iteration 50, residual: 0.000811
# CG iteration 60, residual: 0.000123
# CG iteration 70, residual: 0.000077
# CG iteration 80, residual: 0.000024
# CG iteration 90, residual: 0.000009
# CG iteration 0, residual: 2.006414
# CG iteration 10, residual: 0.064262
# CG iteration 20, residual: 0.025106
# CG iteration 30, residual: 0.004838
# CG iteration 40, residual: 0.001052
# CG iteration 50, residual: 0.000823
# CG iteration 60, residual: 0.000105
# CG iteration 70, residual: 0.000114
# CG iteration 80, residual: 0.000031
# CG iteration 90, residual: 0.000021
# CG iteration 0, residual: 2.091042
# CG iteration 10, residual: 0.065920
# CG iteration 20, residual: 0.007490
# CG iteration 30, residual: 0.003166
# CG iteration 40, residual: 0.000777
# CG iteration 50, residual: 0.000331
# CG iteration 60, residual: 0.000116
# CG iteration 70, residual: 0.000129
# CG iteration 80, residual: 0.000031
# CG iteration 90, residual: 0.000013
# CG iteration 0, residual: 2.191241
# CG iteration 10, residual: 0.073145
# CG iteration 20, residual: 0.014812
# CG iteration 30, residual: 0.004401
# CG iteration 40, residual: 0.002343
# CG iteration 50, residual: 0.000509
# CG iteration 60, residual: 0.000150
# CG iteration 70, residual: 0.000064
# CG iteration 80, residual: 0.000034
# CG iteration 90, residual: 0.000021
# CG iteration 0, residual: 2.301999
# CG iteration 10, residual: 0.056259
# CG iteration 20, residual: 0.006217
# CG iteration 30, residual: 0.005914
# CG iteration 40, residual: 0.001148
# CG iteration 50, residual: 0.000349
# CG iteration 60, residual: 0.000321
# CG iteration 70, residual: 0.000099
# CG iteration 80, residual: 0.000046
# CG iteration 90, residual: 0.000013
# CG iteration 0, residual: 2.417653
# CG iteration 10, residual: 0.059254
# CG iteration 20, residual: 0.006566
# CG iteration 30, residual: 0.005996
# CG iteration 40, residual: 0.001921
# CG iteration 50, residual: 0.000552
# CG iteration 60, residual: 0.000375
# CG iteration 70, residual: 0.000097
# CG iteration 80, residual: 0.000089
# CG iteration 90, residual: 0.000032
# CG iteration 0, residual: 2.532345
# CG iteration 10, residual: 0.041995
# CG iteration 20, residual: 0.008640
# CG iteration 30, residual: 0.005912
# CG iteration 40, residual: 0.001233
# CG iteration 50, residual: 0.001402
# CG iteration 60, residual: 0.000239
# CG iteration 70, residual: 0.000211
# CG iteration 80, residual: 0.000038
# CG iteration 90, residual: 0.000015
# CG iteration 0, residual: 2.640374
# CG iteration 10, residual: 0.054480
# CG iteration 20, residual: 0.019753
# CG iteration 30, residual: 0.005946
# CG iteration 40, residual: 0.003859
# CG iteration 50, residual: 0.003404
# CG iteration 60, residual: 0.000217
# CG iteration 70, residual: 0.000185
# CG iteration 80, residual: 0.000072
# CG iteration 90, residual: 0.000021
# CG iteration 0, residual: 2.736453
# CG iteration 10, residual: 0.029422
# CG iteration 20, residual: 0.022147
# CG iteration 30, residual: 0.003867
# CG iteration 40, residual: 0.002888
# CG iteration 50, residual: 0.001318
# CG iteration 60, residual: 0.000389
# CG iteration 70, residual: 0.000127
# CG iteration 80, residual: 0.000055
# CG iteration 90, residual: 0.000025
# CG iteration 0, residual: 2.815908
# CG iteration 10, residual: 0.044875
# CG iteration 20, residual: 0.016961
# CG iteration 30, residual: 0.006640
# CG iteration 40, residual: 0.004789
# CG iteration 50, residual: 0.000978
# CG iteration 60, residual: 0.000368
# CG iteration 70, residual: 0.000141
# CG iteration 80, residual: 0.000069
# CG iteration 90, residual: 0.000008
# CG iteration 0, residual: 2.874814
# CG iteration 10, residual: 0.112308
# CG iteration 20, residual: 0.032511
# CG iteration 30, residual: 0.008155
# CG iteration 40, residual: 0.003826
# CG iteration 50, residual: 0.000563
# CG iteration 60, residual: 0.000250
# CG iteration 70, residual: 0.000044
# CG iteration 80, residual: 0.000074
# CG iteration 90, residual: 0.000014
# CG iteration 0, residual: 2.910109
# CG iteration 10, residual: 0.205786
# CG iteration 20, residual: 0.056932
# CG iteration 30, residual: 0.009780
# CG iteration 40, residual: 0.002915
# CG iteration 50, residual: 0.001282
# CG iteration 60, residual: 0.000558
# CG iteration 70, residual: 0.000151
# CG iteration 80, residual: 0.000110
# CG iteration 90, residual: 0.000018
# CG iteration 0, residual: 2.919665
# CG iteration 10, residual: 0.299578
# CG iteration 20, residual: 0.067506
# CG iteration 30, residual: 0.011546
# CG iteration 40, residual: 0.002620
# CG iteration 50, residual: 0.001925
# CG iteration 60, residual: 0.000509
# CG iteration 70, residual: 0.000309
# CG iteration 80, residual: 0.000324
# CG iteration 90, residual: 0.000059

# %%
# Benchmark function for GPR
def benchmark_gpr(sizes, kernel_fn, noise_level=0.1):
    predict_times = []
    rmse_scores = []
    all_predictions = []
    
    # Create a fixed test set for consistent evaluation
    X_test = np.linspace(0, 10, 100)[:, None]
    y_test_true = np.sin(X_test).flatten()
    
    for n in sizes:
        # Generate sample data
        X_train = np.linspace(0, 10, n)[:, None]
        y_train = np.sin(X_train).flatten() + 0.1 * np.random.randn(n)

        # Create and fit GPR model
        gpr = GaussianProcessRegression(kernel_fn, noise_level)
        
        # Fit the model (no timing)
        gpr.fit(X_train, y_train)
        
        # Time prediction and evaluate
        start_predict = time.time()
        y_mean, y_var = gpr.predict(X_test)
        end_predict = time.time()
        predict_times.append(end_predict - start_predict)
        
        # Calculate RMSE
        rmse = np.sqrt(mean_squared_error(y_test_true, y_mean))
        rmse_scores.append(rmse)
        
        # Store predictions for plotting
        all_predictions.append((X_train, y_train, X_test, y_mean, y_var, y_test_true, rmse))
        
        print(f"n={n}, predict_time={predict_times[-1]:.3f}s, RMSE={rmse:.4f}")
    
    return predict_times, rmse_scores, all_predictions

# Example usage and testing
if __name__ == "__main__":
    # Run GPR benchmark for multiple sizes
    gpr_sizes = [1000, 2000, 4000, 6000]
    print("Running GPR benchmark for multiple sizes...")
    gpr_predict_times, gpr_rmse_scores, all_predictions = benchmark_gpr(gpr_sizes, rbf_kernel)

    # Plot observation plots for all n's (dynamic subplot grid)
    n_plots = len(gpr_sizes)
    n_cols = 2
    n_rows = int(np.ceil(n_plots / n_cols))

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows))
    axes = axes.ravel()
    
    for i, (size, (X_train, y_train, X_test, y_mean, y_var, y_test_true, rmse)) in enumerate(zip(gpr_sizes, all_predictions)):
        axes[i].plot(X_train, y_train, 'k.', label='Observations', alpha=0.6)
        axes[i].plot(X_test, y_test_true, 'r-', label='True function', linewidth=2)
        axes[i].plot(X_test, y_mean, 'b-', label='Predicted mean', linewidth=2)
        axes[i].fill_between(
            X_test.flatten(),
            y_mean - 2 * np.sqrt(y_var),
            y_mean + 2 * np.sqrt(y_var),
            alpha=0.2,
            color='blue',
            label='95% confidence interval'
        )
        axes[i].set_xlabel('X')
        axes[i].set_ylabel('y')
        axes[i].set_title(f'GPR with n={size} (RMSE: {rmse:.4f})')
        axes[i].legend()
    
    # Hide unused subplots if grid > number of plots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

    # Plotting GPR benchmark results (predict time and RMSE only)
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.plot(np.log10(gpr_sizes), gpr_predict_times, marker="o", color="orange")
    plt.xlabel("log10(Training set size n)")
    plt.ylabel("Prediction time (s)")
    plt.title("log10(n) vs GPR Prediction Time")

    plt.subplot(1, 2, 2)
    plt.plot(np.log10(gpr_sizes), gpr_rmse_scores, marker="o", color="green")
    plt.xlabel("log10(Training set size n)")
    plt.ylabel("RMSE")
    plt.title("log10(n) vs GPR Prediction Error")

    plt.tight_layout()
    plt.show()
# Out:
# Running GPR benchmark for multiple sizes...
# Building kernel matrix of size 1000x1000...
# Solving linear system with conjugate gradient...
# CG iteration 0, residual: 6.157302
# CG iteration 10, residual: 17.856840
# CG iteration 20, residual: 4.079403
# CG iteration 30, residual: 0.547523
# CG iteration 40, residual: 0.272885
# CG iteration 50, residual: 0.224264
# CG iteration 60, residual: 0.088183
# CG iteration 70, residual: 0.034380
# CG iteration 80, residual: 0.016221
# CG iteration 90, residual: 0.003841
# Training completed!
# Making predictions...
# CG iteration 0, residual: 4.134896
# CG iteration 10, residual: 0.455439
# CG iteration 20, residual: 0.115529
# CG iteration 30, residual: 0.030155
# CG iteration 40, residual: 0.046543
# CG iteration 50, residual: 0.007944
# CG iteration 60, residual: 0.007645
# CG iteration 70, residual: 0.001620
# CG iteration 80, residual: 0.001699
# CG iteration 90, residual: 0.001454
# CG iteration 0, residual: 4.123386
# CG iteration 10, residual: 0.310764
# CG iteration 20, residual: 0.085330
# CG iteration 30, residual: 0.029434
# CG iteration 40, residual: 0.034891
# CG iteration 50, residual: 0.008899
# CG iteration 60, residual: 0.003309
# CG iteration 70, residual: 0.003626
# CG iteration 80, residual: 0.003353
# CG iteration 90, residual: 0.000461
# CG iteration 0, residual: 4.075401
# CG iteration 10, residual: 0.169423
# CG iteration 20, residual: 0.060525
# CG iteration 30, residual: 0.020643
# CG iteration 40, residual: 0.028108
# CG iteration 50, residual: 0.004339
# CG iteration 60, residual: 0.002819
# CG iteration 70, residual: 0.002423
# CG iteration 80, residual: 0.001864
# CG iteration 90, residual: 0.000596
# CG iteration 0, residual: 3.993900
# CG iteration 10, residual: 0.063975
# CG iteration 20, residual: 0.054824
# CG iteration 30, residual: 0.018058
# CG iteration 40, residual: 0.016208
# CG iteration 50, residual: 0.006231
# CG iteration 60, residual: 0.002212
# CG iteration 70, residual: 0.002134
# CG iteration 80, residual: 0.000441
# CG iteration 90, residual: 0.000891
# CG iteration 0, residual: 3.883176
# CG iteration 10, residual: 0.034990
# CG iteration 20, residual: 0.058736
# CG iteration 30, residual: 0.021843
# CG iteration 40, residual: 0.013337
# CG iteration 50, residual: 0.006654
# CG iteration 60, residual: 0.004733
# CG iteration 70, residual: 0.003601
# CG iteration 80, residual: 0.001689
# CG iteration 90, residual: 0.001169
# CG iteration 0, residual: 3.748744
# CG iteration 10, residual: 0.073417
# CG iteration 20, residual: 0.050096
# CG iteration 30, residual: 0.016674
# CG iteration 40, residual: 0.026273
# CG iteration 50, residual: 0.008765
# CG iteration 60, residual: 0.009486
# CG iteration 70, residual: 0.005977
# CG iteration 80, residual: 0.002013
# CG iteration 90, residual: 0.001492
# CG iteration 0, residual: 3.597187
# CG iteration 10, residual: 0.057739
# CG iteration 20, residual: 0.031295
# CG iteration 30, residual: 0.016179
# CG iteration 40, residual: 0.013306
# CG iteration 50, residual: 0.010070
# CG iteration 60, residual: 0.006265
# CG iteration 70, residual: 0.011324
# CG iteration 80, residual: 0.002089
# CG iteration 90, residual: 0.002043
# CG iteration 0, residual: 3.435959
# CG iteration 10, residual: 0.085474
# CG iteration 20, residual: 0.036820
# CG iteration 30, residual: 0.022012
# CG iteration 40, residual: 0.024661
# CG iteration 50, residual: 0.019818
# CG iteration 60, residual: 0.001999
# CG iteration 70, residual: 0.002962
# CG iteration 80, residual: 0.003376
# CG iteration 90, residual: 0.001710
# CG iteration 0, residual: 3.273107
# CG iteration 10, residual: 0.071115
# CG iteration 20, residual: 0.045291
# CG iteration 30, residual: 0.056002
# CG iteration 40, residual: 0.027105
# CG iteration 50, residual: 0.005354
# CG iteration 60, residual: 0.003872
# CG iteration 70, residual: 0.003200
# CG iteration 80, residual: 0.004035
# CG iteration 90, residual: 0.001690
# CG iteration 0, residual: 3.116903
# CG iteration 10, residual: 0.100447
# CG iteration 20, residual: 0.030451
# CG iteration 30, residual: 0.059341
# CG iteration 40, residual: 0.006631
# CG iteration 50, residual: 0.003680
# CG iteration 60, residual: 0.001472
# CG iteration 70, residual: 0.002135
# CG iteration 80, residual: 0.000498
# CG iteration 90, residual: 0.000643
# CG iteration 0, residual: 2.975349
# CG iteration 10, residual: 0.096964
# CG iteration 20, residual: 0.035736
# CG iteration 30, residual: 0.023059
# CG iteration 40, residual: 0.006641
# CG iteration 50, residual: 0.006198
# CG iteration 60, residual: 0.002033
# CG iteration 70, residual: 0.004740
# CG iteration 80, residual: 0.001261
# CG iteration 90, residual: 0.000860
# CG iteration 0, residual: 2.855528
# CG iteration 10, residual: 0.096920
# CG iteration 20, residual: 0.059501
# CG iteration 30, residual: 0.037017
# CG iteration 40, residual: 0.016894
# CG iteration 50, residual: 0.009883
# CG iteration 60, residual: 0.000847
# CG iteration 70, residual: 0.003173
# CG iteration 80, residual: 0.000444
# CG iteration 90, residual: 0.000907
# CG iteration 0, residual: 2.762870
# CG iteration 10, residual: 0.099159
# CG iteration 20, residual: 0.069046
# CG iteration 30, residual: 0.031577
# CG iteration 40, residual: 0.012682
# CG iteration 50, residual: 0.006245
# CG iteration 60, residual: 0.002425
# CG iteration 70, residual: 0.001683
# CG iteration 80, residual: 0.001813
# CG iteration 90, residual: 0.000346
# CG iteration 0, residual: 2.700464
# CG iteration 10, residual: 0.074149
# CG iteration 20, residual: 0.043502
# CG iteration 30, residual: 0.013378
# CG iteration 40, residual: 0.011564
# CG iteration 50, residual: 0.005934
# CG iteration 60, residual: 0.002700
# CG iteration 70, residual: 0.000897
# CG iteration 80, residual: 0.001688
# CG iteration 90, residual: 0.000220
# CG iteration 0, residual: 2.668662
# CG iteration 10, residual: 0.075801
# CG iteration 20, residual: 0.036908
# CG iteration 30, residual: 0.011648
# CG iteration 40, residual: 0.002793
# CG iteration 50, residual: 0.003999
# CG iteration 60, residual: 0.000816
# CG iteration 70, residual: 0.001000
# CG iteration 80, residual: 0.000533
# CG iteration 90, residual: 0.000456
# CG iteration 0, residual: 2.665155
# CG iteration 10, residual: 0.117966
# CG iteration 20, residual: 0.037101
# CG iteration 30, residual: 0.009900
# CG iteration 40, residual: 0.008894
# CG iteration 50, residual: 0.004006
# CG iteration 60, residual: 0.001716
# CG iteration 70, residual: 0.000399
# CG iteration 80, residual: 0.000434
# CG iteration 90, residual: 0.001283
# CG iteration 0, residual: 2.685552
# CG iteration 10, residual: 0.186807
# CG iteration 20, residual: 0.029189
# CG iteration 30, residual: 0.006942
# CG iteration 40, residual: 0.009722
# CG iteration 50, residual: 0.004314
# CG iteration 60, residual: 0.001342
# CG iteration 70, residual: 0.000797
# CG iteration 80, residual: 0.000984
# CG iteration 90, residual: 0.000175
# CG iteration 0, residual: 2.724250
# CG iteration 10, residual: 0.103000
# CG iteration 20, residual: 0.036443
# CG iteration 30, residual: 0.006592
# CG iteration 40, residual: 0.020250
# CG iteration 50, residual: 0.002092
# CG iteration 60, residual: 0.001464
# CG iteration 70, residual: 0.001107
# CG iteration 80, residual: 0.000269
# CG iteration 90, residual: 0.000924
# CG iteration 0, residual: 2.775360
# CG iteration 10, residual: 0.058962
# CG iteration 20, residual: 0.033759
# CG iteration 30, residual: 0.010273
# CG iteration 40, residual: 0.006262
# CG iteration 50, residual: 0.003328
# CG iteration 60, residual: 0.003527
# CG iteration 70, residual: 0.000854
# CG iteration 80, residual: 0.001487
# CG iteration 90, residual: 0.000246
# CG iteration 0, residual: 2.833411
# CG iteration 10, residual: 0.067801
# CG iteration 20, residual: 0.028586
# CG iteration 30, residual: 0.023985
# CG iteration 40, residual: 0.007860
# CG iteration 50, residual: 0.002786
# CG iteration 60, residual: 0.001344
# CG iteration 70, residual: 0.000658
# CG iteration 80, residual: 0.001163
# CG iteration 90, residual: 0.000417
# CG iteration 0, residual: 2.893790
# CG iteration 10, residual: 0.096484
# CG iteration 20, residual: 0.014354
# CG iteration 30, residual: 0.011736
# CG iteration 40, residual: 0.006065
# CG iteration 50, residual: 0.005820
# CG iteration 60, residual: 0.001162
# CG iteration 70, residual: 0.000940
# CG iteration 80, residual: 0.001201
# CG iteration 90, residual: 0.000484
# CG iteration 0, residual: 2.952923
# CG iteration 10, residual: 0.076319
# CG iteration 20, residual: 0.036228
# CG iteration 30, residual: 0.025491
# CG iteration 40, residual: 0.009516
# CG iteration 50, residual: 0.010667
# CG iteration 60, residual: 0.001930
# CG iteration 70, residual: 0.001607
# CG iteration 80, residual: 0.000564
# CG iteration 90, residual: 0.000503
# CG iteration 0, residual: 3.008282
# CG iteration 10, residual: 0.053663
# CG iteration 20, residual: 0.077160
# CG iteration 30, residual: 0.016341
# CG iteration 40, residual: 0.009044
# CG iteration 50, residual: 0.006983
# CG iteration 60, residual: 0.001803
# CG iteration 70, residual: 0.002605
# CG iteration 80, residual: 0.000535
# CG iteration 90, residual: 0.000609
# CG iteration 0, residual: 3.058276
# CG iteration 10, residual: 0.074692
# CG iteration 20, residual: 0.071583
# CG iteration 30, residual: 0.012665
# CG iteration 40, residual: 0.008971
# CG iteration 50, residual: 0.015171
# CG iteration 60, residual: 0.005025
# CG iteration 70, residual: 0.002249
# CG iteration 80, residual: 0.001378
# CG iteration 90, residual: 0.000615
# CG iteration 0, residual: 3.102092
# CG iteration 10, residual: 0.077437
# CG iteration 20, residual: 0.055810
# CG iteration 30, residual: 0.026160
# CG iteration 40, residual: 0.016825
# CG iteration 50, residual: 0.008727
# CG iteration 60, residual: 0.003375
# CG iteration 70, residual: 0.003391
# CG iteration 80, residual: 0.000863
# CG iteration 90, residual: 0.000305
# CG iteration 0, residual: 3.139521
# CG iteration 10, residual: 0.092156
# CG iteration 20, residual: 0.042789
# CG iteration 30, residual: 0.015647
# CG iteration 40, residual: 0.010744
# CG iteration 50, residual: 0.009564
# CG iteration 60, residual: 0.005991
# CG iteration 70, residual: 0.002748
# CG iteration 80, residual: 0.002837
# CG iteration 90, residual: 0.000767
# CG iteration 0, residual: 3.170785
# CG iteration 10, residual: 0.112596
# CG iteration 20, residual: 0.017515
# CG iteration 30, residual: 0.018173
# CG iteration 40, residual: 0.016939
# CG iteration 50, residual: 0.010260
# CG iteration 60, residual: 0.004469
# CG iteration 70, residual: 0.002218
# CG iteration 80, residual: 0.001954
# CG iteration 90, residual: 0.001027
# CG iteration 0, residual: 3.196400
# CG iteration 10, residual: 0.108816
# CG iteration 20, residual: 0.038076
# CG iteration 30, residual: 0.024877
# CG iteration 40, residual: 0.015067
# CG iteration 50, residual: 0.020158
# CG iteration 60, residual: 0.006008
# CG iteration 70, residual: 0.003216
# CG iteration 80, residual: 0.000704
# CG iteration 90, residual: 0.000367
# CG iteration 0, residual: 3.217036
# CG iteration 10, residual: 0.102251
# CG iteration 20, residual: 0.046600
# CG iteration 30, residual: 0.010950
# CG iteration 40, residual: 0.010338
# CG iteration 50, residual: 0.005692
# CG iteration 60, residual: 0.002931
# CG iteration 70, residual: 0.003076
# CG iteration 80, residual: 0.001367
# CG iteration 90, residual: 0.000629
# CG iteration 0, residual: 3.233430
# CG iteration 10, residual: 0.079093
# CG iteration 20, residual: 0.072493
# CG iteration 30, residual: 0.031323
# CG iteration 40, residual: 0.018610
# CG iteration 50, residual: 0.007633
# CG iteration 60, residual: 0.003529
# CG iteration 70, residual: 0.001849
# CG iteration 80, residual: 0.001089
# CG iteration 90, residual: 0.000430
# CG iteration 0, residual: 3.246317
# CG iteration 10, residual: 0.053344
# CG iteration 20, residual: 0.073192
# CG iteration 30, residual: 0.024766
# CG iteration 40, residual: 0.009073
# CG iteration 50, residual: 0.010528
# CG iteration 60, residual: 0.005944
# CG iteration 70, residual: 0.003297
# CG iteration 80, residual: 0.003077
# CG iteration 90, residual: 0.000720
# CG iteration 0, residual: 3.256370
# CG iteration 10, residual: 0.072625
# CG iteration 20, residual: 0.041273
# CG iteration 30, residual: 0.014101
# CG iteration 40, residual: 0.010644
# CG iteration 50, residual: 0.013129
# CG iteration 60, residual: 0.004312
# CG iteration 70, residual: 0.005115
# CG iteration 80, residual: 0.001708
# CG iteration 90, residual: 0.000893
# CG iteration 0, residual: 3.264180
# CG iteration 10, residual: 0.053749
# CG iteration 20, residual: 0.058864
# CG iteration 30, residual: 0.022183
# CG iteration 40, residual: 0.008369
# CG iteration 50, residual: 0.003988
# CG iteration 60, residual: 0.004469
# CG iteration 70, residual: 0.001571
# CG iteration 80, residual: 0.000705
# CG iteration 90, residual: 0.001238
# CG iteration 0, residual: 3.270244
# CG iteration 10, residual: 0.069147
# CG iteration 20, residual: 0.046192
# CG iteration 30, residual: 0.022550
# CG iteration 40, residual: 0.007720
# CG iteration 50, residual: 0.008646
# CG iteration 60, residual: 0.003735
# CG iteration 70, residual: 0.001875
# CG iteration 80, residual: 0.000792
# CG iteration 90, residual: 0.001251
# CG iteration 0, residual: 3.274958
# CG iteration 10, residual: 0.077583
# CG iteration 20, residual: 0.053954
# CG iteration 30, residual: 0.021858
# CG iteration 40, residual: 0.006950
# CG iteration 50, residual: 0.002160
# CG iteration 60, residual: 0.002427
# CG iteration 70, residual: 0.003822
# CG iteration 80, residual: 0.001213
# CG iteration 90, residual: 0.000551
# CG iteration 0, residual: 3.278631
# CG iteration 10, residual: 0.061894
# CG iteration 20, residual: 0.026830
# CG iteration 30, residual: 0.012394
# CG iteration 40, residual: 0.009159
# CG iteration 50, residual: 0.002960
# CG iteration 60, residual: 0.006659
# CG iteration 70, residual: 0.003783
# CG iteration 80, residual: 0.000763
# CG iteration 90, residual: 0.000189
# CG iteration 0, residual: 3.281488
# CG iteration 10, residual: 0.059538
# CG iteration 20, residual: 0.058172
# CG iteration 30, residual: 0.005402
# CG iteration 40, residual: 0.006189
# CG iteration 50, residual: 0.004608
# CG iteration 60, residual: 0.002104
# CG iteration 70, residual: 0.001765
# CG iteration 80, residual: 0.001382
# CG iteration 90, residual: 0.000370
# CG iteration 0, residual: 3.283690
# CG iteration 10, residual: 0.103830
# CG iteration 20, residual: 0.054799
# CG iteration 30, residual: 0.012356
# CG iteration 40, residual: 0.007942
# CG iteration 50, residual: 0.004295
# CG iteration 60, residual: 0.003355
# CG iteration 70, residual: 0.001212
# CG iteration 80, residual: 0.002533
# CG iteration 90, residual: 0.000886
# CG iteration 0, residual: 3.285348
# CG iteration 10, residual: 0.121149
# CG iteration 20, residual: 0.017316
# CG iteration 30, residual: 0.010803
# CG iteration 40, residual: 0.012299
# CG iteration 50, residual: 0.006121
# CG iteration 60, residual: 0.001664
# CG iteration 70, residual: 0.000881
# CG iteration 80, residual: 0.000828
# CG iteration 90, residual: 0.000962
# CG iteration 0, residual: 3.286537
# CG iteration 10, residual: 0.118388
# CG iteration 20, residual: 0.057023
# CG iteration 30, residual: 0.007296
# CG iteration 40, residual: 0.007247
# CG iteration 50, residual: 0.007758
# CG iteration 60, residual: 0.001607
# CG iteration 70, residual: 0.000584
# CG iteration 80, residual: 0.000367
# CG iteration 90, residual: 0.000145
# CG iteration 0, residual: 3.287311
# CG iteration 10, residual: 0.107922
# CG iteration 20, residual: 0.021984
# CG iteration 30, residual: 0.015587
# CG iteration 40, residual: 0.002877
# CG iteration 50, residual: 0.004058
# CG iteration 60, residual: 0.000627
# CG iteration 70, residual: 0.001256
# CG iteration 80, residual: 0.000406
# CG iteration 90, residual: 0.000336
# CG iteration 0, residual: 3.287708
# CG iteration 10, residual: 0.090166
# CG iteration 20, residual: 0.014334
# CG iteration 30, residual: 0.008948
# CG iteration 40, residual: 0.004575
# CG iteration 50, residual: 0.003470
# CG iteration 60, residual: 0.001195
# CG iteration 70, residual: 0.000961
# CG iteration 80, residual: 0.001023
# CG iteration 90, residual: 0.000344
# CG iteration 0, residual: 3.287765
# CG iteration 10, residual: 0.065918
# CG iteration 20, residual: 0.019993
# CG iteration 30, residual: 0.008860
# CG iteration 40, residual: 0.009048
# CG iteration 50, residual: 0.001095
# CG iteration 60, residual: 0.003876
# CG iteration 70, residual: 0.000198
# CG iteration 80, residual: 0.000282
# CG iteration 90, residual: 0.000154
# CG iteration 0, residual: 3.287522
# CG iteration 10, residual: 0.041638
# CG iteration 20, residual: 0.015921
# CG iteration 30, residual: 0.003171
# CG iteration 40, residual: 0.006686
# CG iteration 50, residual: 0.005503
# CG iteration 60, residual: 0.001234
# CG iteration 70, residual: 0.000564
# CG iteration 80, residual: 0.000319
# CG iteration 90, residual: 0.000224
# CG iteration 0, residual: 3.287029
# CG iteration 10, residual: 0.048060
# CG iteration 20, residual: 0.022911
# CG iteration 30, residual: 0.007306
# CG iteration 40, residual: 0.007467
# CG iteration 50, residual: 0.002270
# CG iteration 60, residual: 0.001380
# CG iteration 70, residual: 0.000615
# CG iteration 80, residual: 0.000461
# CG iteration 90, residual: 0.000112
# CG iteration 0, residual: 3.286342
# CG iteration 10, residual: 0.077549
# CG iteration 20, residual: 0.019293
# CG iteration 30, residual: 0.010231
# CG iteration 40, residual: 0.009093
# CG iteration 50, residual: 0.002691
# CG iteration 60, residual: 0.001132
# CG iteration 70, residual: 0.000460
# CG iteration 80, residual: 0.000751
# CG iteration 90, residual: 0.000260
# CG iteration 0, residual: 3.285522
# CG iteration 10, residual: 0.123884
# CG iteration 20, residual: 0.044431
# CG iteration 30, residual: 0.013391
# CG iteration 40, residual: 0.011973
# CG iteration 50, residual: 0.004254
# CG iteration 60, residual: 0.002850
# CG iteration 70, residual: 0.000575
# CG iteration 80, residual: 0.000766
# CG iteration 90, residual: 0.000327
# CG iteration 0, residual: 3.284639
# CG iteration 10, residual: 0.164575
# CG iteration 20, residual: 0.025253
# CG iteration 30, residual: 0.006854
# CG iteration 40, residual: 0.007723
# CG iteration 50, residual: 0.005722
# CG iteration 60, residual: 0.003767
# CG iteration 70, residual: 0.001793
# CG iteration 80, residual: 0.000847
# CG iteration 90, residual: 0.000342
# CG iteration 0, residual: 3.283762
# CG iteration 10, residual: 0.148614
# CG iteration 20, residual: 0.022658
# CG iteration 30, residual: 0.008015
# CG iteration 40, residual: 0.004066
# CG iteration 50, residual: 0.006527
# CG iteration 60, residual: 0.002113
# CG iteration 70, residual: 0.002315
# CG iteration 80, residual: 0.000587
# CG iteration 90, residual: 0.000417
# CG iteration 0, residual: 3.282959
# CG iteration 10, residual: 0.097092
# CG iteration 20, residual: 0.025893
# CG iteration 30, residual: 0.009607
# CG iteration 40, residual: 0.005405
# CG iteration 50, residual: 0.004101
# CG iteration 60, residual: 0.003127
# CG iteration 70, residual: 0.000475
# CG iteration 80, residual: 0.000777
# CG iteration 90, residual: 0.000206
# CG iteration 0, residual: 3.282288
# CG iteration 10, residual: 0.072473
# CG iteration 20, residual: 0.027366
# CG iteration 30, residual: 0.017613
# CG iteration 40, residual: 0.002212
# CG iteration 50, residual: 0.008324
# CG iteration 60, residual: 0.001024
# CG iteration 70, residual: 0.000675
# CG iteration 80, residual: 0.000400
# CG iteration 90, residual: 0.000364
# CG iteration 0, residual: 3.281796
# CG iteration 10, residual: 0.118526
# CG iteration 20, residual: 0.059522
# CG iteration 30, residual: 0.015270
# CG iteration 40, residual: 0.007652
# CG iteration 50, residual: 0.013225
# CG iteration 60, residual: 0.002189
# CG iteration 70, residual: 0.002738
# CG iteration 80, residual: 0.000409
# CG iteration 90, residual: 0.000409
# CG iteration 0, residual: 3.281520
# CG iteration 10, residual: 0.104922
# CG iteration 20, residual: 0.071850
# CG iteration 30, residual: 0.015897
# CG iteration 40, residual: 0.019020
# CG iteration 50, residual: 0.005472
# CG iteration 60, residual: 0.003862
# CG iteration 70, residual: 0.002135
# CG iteration 80, residual: 0.000660
# CG iteration 90, residual: 0.000685
# CG iteration 0, residual: 3.281475
# CG iteration 10, residual: 0.083626
# CG iteration 20, residual: 0.069435
# CG iteration 30, residual: 0.023214
# CG iteration 40, residual: 0.018665
# CG iteration 50, residual: 0.008463
# CG iteration 60, residual: 0.005613
# CG iteration 70, residual: 0.001888
# CG iteration 80, residual: 0.000880
# CG iteration 90, residual: 0.000521
# CG iteration 0, residual: 3.281660
# CG iteration 10, residual: 0.061843
# CG iteration 20, residual: 0.038824
# CG iteration 30, residual: 0.011945
# CG iteration 40, residual: 0.016543
# CG iteration 50, residual: 0.006934
# CG iteration 60, residual: 0.001588
# CG iteration 70, residual: 0.000473
# CG iteration 80, residual: 0.000634
# CG iteration 90, residual: 0.000324
# CG iteration 0, residual: 3.282056
# CG iteration 10, residual: 0.044437
# CG iteration 20, residual: 0.034953
# CG iteration 30, residual: 0.031239
# CG iteration 40, residual: 0.021142
# CG iteration 50, residual: 0.005765
# CG iteration 60, residual: 0.002190
# CG iteration 70, residual: 0.002012
# CG iteration 80, residual: 0.000577
# CG iteration 90, residual: 0.000465
# CG iteration 0, residual: 3.282626
# CG iteration 10, residual: 0.044143
# CG iteration 20, residual: 0.035458
# CG iteration 30, residual: 0.018265
# CG iteration 40, residual: 0.008138
# CG iteration 50, residual: 0.009947
# CG iteration 60, residual: 0.002881
# CG iteration 70, residual: 0.003509
# CG iteration 80, residual: 0.000768
# CG iteration 90, residual: 0.000995
# CG iteration 0, residual: 3.283314
# CG iteration 10, residual: 0.072778
# CG iteration 20, residual: 0.043803
# CG iteration 30, residual: 0.018763
# CG iteration 40, residual: 0.017474
# CG iteration 50, residual: 0.005564
# CG iteration 60, residual: 0.003934
# CG iteration 70, residual: 0.001188
# CG iteration 80, residual: 0.001207
# CG iteration 90, residual: 0.000731
# CG iteration 0, residual: 3.284051
# CG iteration 10, residual: 0.096740
# CG iteration 20, residual: 0.041471
# CG iteration 30, residual: 0.017011
# CG iteration 40, residual: 0.009938
# CG iteration 50, residual: 0.008720
# CG iteration 60, residual: 0.001499
# CG iteration 70, residual: 0.002496
# CG iteration 80, residual: 0.000628
# CG iteration 90, residual: 0.000177
# CG iteration 0, residual: 3.284748
# CG iteration 10, residual: 0.120106
# CG iteration 20, residual: 0.064161
# CG iteration 30, residual: 0.016117
# CG iteration 40, residual: 0.014055
# CG iteration 50, residual: 0.005834
# CG iteration 60, residual: 0.001294
# CG iteration 70, residual: 0.001018
# CG iteration 80, residual: 0.001416
# CG iteration 90, residual: 0.000728
# CG iteration 0, residual: 3.285297
# CG iteration 10, residual: 0.129911
# CG iteration 20, residual: 0.043981
# CG iteration 30, residual: 0.015143
# CG iteration 40, residual: 0.007300
# CG iteration 50, residual: 0.009803
# CG iteration 60, residual: 0.003692
# CG iteration 70, residual: 0.000995
# CG iteration 80, residual: 0.000162
# CG iteration 90, residual: 0.000240
# CG iteration 0, residual: 3.285579
# CG iteration 10, residual: 0.127294
# CG iteration 20, residual: 0.025512
# CG iteration 30, residual: 0.016004
# CG iteration 40, residual: 0.016505
# CG iteration 50, residual: 0.006117
# CG iteration 60, residual: 0.003131
# CG iteration 70, residual: 0.001186
# CG iteration 80, residual: 0.000477
# CG iteration 90, residual: 0.000259
# CG iteration 0, residual: 3.285444
# CG iteration 10, residual: 0.112214
# CG iteration 20, residual: 0.040281
# CG iteration 30, residual: 0.025300
# CG iteration 40, residual: 0.006320
# CG iteration 50, residual: 0.004433
# CG iteration 60, residual: 0.001722
# CG iteration 70, residual: 0.001458
# CG iteration 80, residual: 0.000628
# CG iteration 90, residual: 0.000083
# CG iteration 0, residual: 3.284723
# CG iteration 10, residual: 0.071068
# CG iteration 20, residual: 0.024297
# CG iteration 30, residual: 0.018793
# CG iteration 40, residual: 0.009813
# CG iteration 50, residual: 0.003226
# CG iteration 60, residual: 0.003592
# CG iteration 70, residual: 0.000896
# CG iteration 80, residual: 0.001458
# CG iteration 90, residual: 0.000132
# CG iteration 0, residual: 3.283208
# CG iteration 10, residual: 0.060002
# CG iteration 20, residual: 0.030206
# CG iteration 30, residual: 0.008448
# CG iteration 40, residual: 0.008049
# CG iteration 50, residual: 0.001953
# CG iteration 60, residual: 0.001954
# CG iteration 70, residual: 0.000627
# CG iteration 80, residual: 0.001278
# CG iteration 90, residual: 0.000258
# CG iteration 0, residual: 3.280651
# CG iteration 10, residual: 0.079736
# CG iteration 20, residual: 0.040576
# CG iteration 30, residual: 0.007574
# CG iteration 40, residual: 0.002247
# CG iteration 50, residual: 0.002982
# CG iteration 60, residual: 0.001470
# CG iteration 70, residual: 0.001140
# CG iteration 80, residual: 0.000502
# CG iteration 90, residual: 0.000198
# CG iteration 0, residual: 3.276754
# CG iteration 10, residual: 0.071356
# CG iteration 20, residual: 0.036609
# CG iteration 30, residual: 0.004017
# CG iteration 40, residual: 0.004361
# CG iteration 50, residual: 0.001684
# CG iteration 60, residual: 0.001685
# CG iteration 70, residual: 0.000553
# CG iteration 80, residual: 0.000500
# CG iteration 90, residual: 0.000135
# CG iteration 0, residual: 3.271159
# CG iteration 10, residual: 0.055998
# CG iteration 20, residual: 0.044928
# CG iteration 30, residual: 0.005056
# CG iteration 40, residual: 0.007826
# CG iteration 50, residual: 0.003538
# CG iteration 60, residual: 0.001850
# CG iteration 70, residual: 0.001092
# CG iteration 80, residual: 0.000941
# CG iteration 90, residual: 0.000426
# CG iteration 0, residual: 3.263434
# CG iteration 10, residual: 0.099312
# CG iteration 20, residual: 0.031334
# CG iteration 30, residual: 0.006211
# CG iteration 40, residual: 0.007181
# CG iteration 50, residual: 0.002294
# CG iteration 60, residual: 0.000856
# CG iteration 70, residual: 0.000902
# CG iteration 80, residual: 0.000438
# CG iteration 90, residual: 0.000768
# CG iteration 0, residual: 3.253075
# CG iteration 10, residual: 0.055673
# CG iteration 20, residual: 0.053353
# CG iteration 30, residual: 0.013818
# CG iteration 40, residual: 0.007383
# CG iteration 50, residual: 0.003935
# CG iteration 60, residual: 0.002360
# CG iteration 70, residual: 0.002185
# CG iteration 80, residual: 0.000908
# CG iteration 90, residual: 0.000680
# CG iteration 0, residual: 3.239499
# CG iteration 10, residual: 0.080366
# CG iteration 20, residual: 0.047329
# CG iteration 30, residual: 0.015170
# CG iteration 40, residual: 0.012281
# CG iteration 50, residual: 0.004591
# CG iteration 60, residual: 0.001270
# CG iteration 70, residual: 0.001048
# CG iteration 80, residual: 0.000286
# CG iteration 90, residual: 0.000405
# CG iteration 0, residual: 3.222062
# CG iteration 10, residual: 0.103424
# CG iteration 20, residual: 0.045063
# CG iteration 30, residual: 0.008575
# CG iteration 40, residual: 0.008604
# CG iteration 50, residual: 0.003762
# CG iteration 60, residual: 0.001528
# CG iteration 70, residual: 0.001139
# CG iteration 80, residual: 0.000973
# CG iteration 90, residual: 0.000496
# CG iteration 0, residual: 3.200078
# CG iteration 10, residual: 0.113331
# CG iteration 20, residual: 0.028826
# CG iteration 30, residual: 0.010882
# CG iteration 40, residual: 0.008722
# CG iteration 50, residual: 0.006336
# CG iteration 60, residual: 0.005626
# CG iteration 70, residual: 0.001371
# CG iteration 80, residual: 0.001107
# CG iteration 90, residual: 0.000390
# CG iteration 0, residual: 3.172868
# CG iteration 10, residual: 0.116918
# CG iteration 20, residual: 0.023523
# CG iteration 30, residual: 0.013240
# CG iteration 40, residual: 0.013236
# CG iteration 50, residual: 0.002601
# CG iteration 60, residual: 0.002885
# CG iteration 70, residual: 0.000736
# CG iteration 80, residual: 0.000752
# CG iteration 90, residual: 0.000539
# CG iteration 0, residual: 3.139826
# CG iteration 10, residual: 0.101288
# CG iteration 20, residual: 0.024013
# CG iteration 30, residual: 0.009057
# CG iteration 40, residual: 0.011103
# CG iteration 50, residual: 0.003474
# CG iteration 60, residual: 0.003587
# CG iteration 70, residual: 0.000882
# CG iteration 80, residual: 0.001028
# CG iteration 90, residual: 0.001072
# CG iteration 0, residual: 3.100509
# CG iteration 10, residual: 0.109837
# CG iteration 20, residual: 0.055399
# CG iteration 30, residual: 0.011383
# CG iteration 40, residual: 0.019481
# CG iteration 50, residual: 0.006480
# CG iteration 60, residual: 0.001205
# CG iteration 70, residual: 0.001827
# CG iteration 80, residual: 0.000466
# CG iteration 90, residual: 0.000265
# CG iteration 0, residual: 3.054762
# CG iteration 10, residual: 0.132713
# CG iteration 20, residual: 0.056855
# CG iteration 30, residual: 0.009520
# CG iteration 40, residual: 0.002757
# CG iteration 50, residual: 0.007424
# CG iteration 60, residual: 0.001111
# CG iteration 70, residual: 0.001044
# CG iteration 80, residual: 0.000632
# CG iteration 90, residual: 0.000393
# CG iteration 0, residual: 3.002865
# CG iteration 10, residual: 0.056794
# CG iteration 20, residual: 0.043344
# CG iteration 30, residual: 0.009932
# CG iteration 40, residual: 0.003686
# CG iteration 50, residual: 0.003075
# CG iteration 60, residual: 0.000441
# CG iteration 70, residual: 0.000676
# CG iteration 80, residual: 0.000782
# CG iteration 90, residual: 0.000107
# CG iteration 0, residual: 2.945694
# CG iteration 10, residual: 0.048422
# CG iteration 20, residual: 0.010370
# CG iteration 30, residual: 0.013788
# CG iteration 40, residual: 0.002380
# CG iteration 50, residual: 0.007565
# CG iteration 60, residual: 0.000754
# CG iteration 70, residual: 0.001244
# CG iteration 80, residual: 0.000556
# CG iteration 90, residual: 0.000491
# CG iteration 0, residual: 2.884906
# CG iteration 10, residual: 0.076547
# CG iteration 20, residual: 0.049377
# CG iteration 30, residual: 0.012910
# CG iteration 40, residual: 0.008244
# CG iteration 50, residual: 0.001783
# CG iteration 60, residual: 0.001725
# CG iteration 70, residual: 0.000369
# CG iteration 80, residual: 0.000639
# CG iteration 90, residual: 0.000309
# CG iteration 0, residual: 2.823086
# CG iteration 10, residual: 0.072283
# CG iteration 20, residual: 0.050327
# CG iteration 30, residual: 0.008895
# CG iteration 40, residual: 0.002973
# CG iteration 50, residual: 0.002369
# CG iteration 60, residual: 0.001442
# CG iteration 70, residual: 0.000536
# CG iteration 80, residual: 0.001035
# CG iteration 90, residual: 0.000201
# CG iteration 0, residual: 2.763861
# CG iteration 10, residual: 0.085356
# CG iteration 20, residual: 0.031501
# CG iteration 30, residual: 0.005378
# CG iteration 40, residual: 0.007939
# CG iteration 50, residual: 0.002052
# CG iteration 60, residual: 0.003136
# CG iteration 70, residual: 0.000543
# CG iteration 80, residual: 0.000609
# CG iteration 90, residual: 0.000158
# CG iteration 0, residual: 2.711898
# CG iteration 10, residual: 0.122495
# CG iteration 20, residual: 0.034826
# CG iteration 30, residual: 0.002526
# CG iteration 40, residual: 0.004605
# CG iteration 50, residual: 0.001758
# CG iteration 60, residual: 0.001481
# CG iteration 70, residual: 0.000756
# CG iteration 80, residual: 0.000470
# CG iteration 90, residual: 0.000185
# CG iteration 0, residual: 2.672713
# CG iteration 10, residual: 0.137537
# CG iteration 20, residual: 0.034288
# CG iteration 30, residual: 0.003227
# CG iteration 40, residual: 0.003486
# CG iteration 50, residual: 0.002058
# CG iteration 60, residual: 0.001428
# CG iteration 70, residual: 0.000342
# CG iteration 80, residual: 0.000265
# CG iteration 90, residual: 0.000124
# CG iteration 0, residual: 2.652228
# CG iteration 10, residual: 0.092971
# CG iteration 20, residual: 0.045103
# CG iteration 30, residual: 0.007607
# CG iteration 40, residual: 0.003969
# CG iteration 50, residual: 0.001249
# CG iteration 60, residual: 0.001419
# CG iteration 70, residual: 0.000537
# CG iteration 80, residual: 0.000255
# CG iteration 90, residual: 0.000385
# CG iteration 0, residual: 2.656044
# CG iteration 10, residual: 0.068070
# CG iteration 20, residual: 0.039732
# CG iteration 30, residual: 0.007864
# CG iteration 40, residual: 0.006382
# CG iteration 50, residual: 0.001238
# CG iteration 60, residual: 0.000555
# CG iteration 70, residual: 0.000370
# CG iteration 80, residual: 0.000844
# CG iteration 90, residual: 0.000351
# CG iteration 0, residual: 2.688521
# CG iteration 10, residual: 0.067220
# CG iteration 20, residual: 0.036995
# CG iteration 30, residual: 0.004325
# CG iteration 40, residual: 0.002937
# CG iteration 50, residual: 0.003666
# CG iteration 60, residual: 0.002428
# CG iteration 70, residual: 0.001187
# CG iteration 80, residual: 0.000201
# CG iteration 90, residual: 0.000114
# CG iteration 0, residual: 2.751899
# CG iteration 10, residual: 0.085380
# CG iteration 20, residual: 0.065643
# CG iteration 30, residual: 0.010976
# CG iteration 40, residual: 0.006954
# CG iteration 50, residual: 0.002009
# CG iteration 60, residual: 0.000424
# CG iteration 70, residual: 0.000779
# CG iteration 80, residual: 0.000211
# CG iteration 90, residual: 0.000081
# CG iteration 0, residual: 2.845729
# CG iteration 10, residual: 0.093123
# CG iteration 20, residual: 0.042005
# CG iteration 30, residual: 0.010693
# CG iteration 40, residual: 0.003623
# CG iteration 50, residual: 0.002353
# CG iteration 60, residual: 0.001601
# CG iteration 70, residual: 0.001048
# CG iteration 80, residual: 0.000394
# CG iteration 90, residual: 0.000168
# CG iteration 0, residual: 2.966809
# CG iteration 10, residual: 0.095862
# CG iteration 20, residual: 0.013521
# CG iteration 30, residual: 0.007661
# CG iteration 40, residual: 0.002573
# CG iteration 50, residual: 0.001244
# CG iteration 60, residual: 0.000706
# CG iteration 70, residual: 0.000432
# CG iteration 80, residual: 0.000265
# CG iteration 90, residual: 0.000072
# CG iteration 0, residual: 3.109621
# CG iteration 10, residual: 0.107677
# CG iteration 20, residual: 0.026442
# CG iteration 30, residual: 0.007940
# CG iteration 40, residual: 0.004428
# CG iteration 50, residual: 0.001653
# CG iteration 60, residual: 0.001248
# CG iteration 70, residual: 0.000529
# CG iteration 80, residual: 0.000563
# CG iteration 90, residual: 0.000204
# CG iteration 0, residual: 3.267007
# CG iteration 10, residual: 0.081458
# CG iteration 20, residual: 0.011351
# CG iteration 30, residual: 0.012349
# CG iteration 40, residual: 0.002781
# CG iteration 50, residual: 0.001214
# CG iteration 60, residual: 0.000742
# CG iteration 70, residual: 0.000269
# CG iteration 80, residual: 0.000334
# CG iteration 90, residual: 0.000133
# CG iteration 0, residual: 3.430925
# CG iteration 10, residual: 0.088250
# CG iteration 20, residual: 0.011645
# CG iteration 30, residual: 0.011394
# CG iteration 40, residual: 0.007464
# CG iteration 50, residual: 0.001994
# CG iteration 60, residual: 0.002301
# CG iteration 70, residual: 0.000657
# CG iteration 80, residual: 0.001190
# CG iteration 90, residual: 0.000468
# CG iteration 0, residual: 3.593080
# CG iteration 10, residual: 0.061082
# CG iteration 20, residual: 0.013709
# CG iteration 30, residual: 0.008962
# CG iteration 40, residual: 0.004694
# CG iteration 50, residual: 0.002725
# CG iteration 60, residual: 0.000999
# CG iteration 70, residual: 0.000945
# CG iteration 80, residual: 0.000369
# CG iteration 90, residual: 0.000292
# CG iteration 0, residual: 3.745424
# CG iteration 10, residual: 0.079528
# CG iteration 20, residual: 0.032850
# CG iteration 30, residual: 0.011085
# CG iteration 40, residual: 0.010591
# CG iteration 50, residual: 0.010143
# CG iteration 60, residual: 0.000990
# CG iteration 70, residual: 0.000694
# CG iteration 80, residual: 0.000662
# CG iteration 90, residual: 0.000361
# CG iteration 0, residual: 3.880512
# CG iteration 10, residual: 0.040861
# CG iteration 20, residual: 0.033063
# CG iteration 30, residual: 0.006371
# CG iteration 40, residual: 0.005411
# CG iteration 50, residual: 0.004178
# CG iteration 60, residual: 0.001449
# CG iteration 70, residual: 0.001053
# CG iteration 80, residual: 0.000283
# CG iteration 90, residual: 0.000333
# CG iteration 0, residual: 3.991772
# CG iteration 10, residual: 0.066667
# CG iteration 20, residual: 0.023994
# CG iteration 30, residual: 0.016415
# CG iteration 40, residual: 0.013100
# CG iteration 50, residual: 0.002676
# CG iteration 60, residual: 0.002709
# CG iteration 70, residual: 0.000762
# CG iteration 80, residual: 0.000581
# CG iteration 90, residual: 0.000078
# CG iteration 0, residual: 4.073705
# CG iteration 10, residual: 0.166175
# CG iteration 20, residual: 0.055231
# CG iteration 30, residual: 0.018839
# CG iteration 40, residual: 0.011548
# CG iteration 50, residual: 0.002314
# CG iteration 60, residual: 0.002747
# CG iteration 70, residual: 0.000285
# CG iteration 80, residual: 0.000968
# CG iteration 90, residual: 0.000167
# CG iteration 0, residual: 4.122036
# CG iteration 10, residual: 0.305347
# CG iteration 20, residual: 0.100857
# CG iteration 30, residual: 0.019252
# CG iteration 40, residual: 0.008424
# CG iteration 50, residual: 0.003277
# CG iteration 60, residual: 0.001320
# CG iteration 70, residual: 0.000828
# CG iteration 80, residual: 0.001612
# CG iteration 90, residual: 0.000256
# CG iteration 0, residual: 4.133818
# CG iteration 10, residual: 0.448206
# CG iteration 20, residual: 0.124406
# CG iteration 30, residual: 0.029815
# CG iteration 40, residual: 0.008233
# CG iteration 50, residual: 0.006788
# CG iteration 60, residual: 0.002123
# CG iteration 70, residual: 0.001836
# CG iteration 80, residual: 0.002584
# CG iteration 90, residual: 0.000858
# n=1000, predict_time=1476.514s, RMSE=0.0156
# Building kernel matrix of size 2000x2000...
# Solving linear system with conjugate gradient...
# CG iteration 0, residual: 8.795225
# CG iteration 10, residual: 39.114628
# CG iteration 20, residual: 8.130798
# CG iteration 30, residual: 2.022173
# CG iteration 40, residual: 0.398316
# CG iteration 50, residual: 1.384212
# CG iteration 60, residual: 1.197854
# CG iteration 70, residual: 0.582020
# CG iteration 80, residual: 0.230766
# CG iteration 90, residual: 0.156509
# Training completed!
# Making predictions...
# CG iteration 0, residual: 5.850855
# CG iteration 10, residual: 0.663013
# CG iteration 20, residual: 0.183597
# CG iteration 30, residual: 0.053390
# CG iteration 40, residual: 0.080962
# CG iteration 50, residual: 0.019023
# CG iteration 60, residual: 0.030243
# CG iteration 70, residual: 0.006571
# CG iteration 80, residual: 0.012971
# CG iteration 90, residual: 0.009350
# CG iteration 0, residual: 5.835794
# CG iteration 10, residual: 0.453382
# CG iteration 20, residual: 0.133506
# CG iteration 30, residual: 0.051495
# CG iteration 40, residual: 0.079257
# CG iteration 50, residual: 0.023852
# CG iteration 60, residual: 0.008593
# CG iteration 70, residual: 0.013344
# CG iteration 80, residual: 0.015808
# CG iteration 90, residual: 0.003244
# CG iteration 0, residual: 5.769038
# CG iteration 10, residual: 0.248120
# CG iteration 20, residual: 0.093109
# CG iteration 30, residual: 0.037052
# CG iteration 40, residual: 0.072614
# CG iteration 50, residual: 0.015689
# CG iteration 60, residual: 0.007603
# CG iteration 70, residual: 0.013612
# CG iteration 80, residual: 0.016191
# CG iteration 90, residual: 0.020282
# CG iteration 0, residual: 5.654737
# CG iteration 10, residual: 0.094103
# CG iteration 20, residual: 0.085350
# CG iteration 30, residual: 0.040546
# CG iteration 40, residual: 0.044234
# CG iteration 50, residual: 0.019474
# CG iteration 60, residual: 0.009466
# CG iteration 70, residual: 0.018753
# CG iteration 80, residual: 0.005425
# CG iteration 90, residual: 0.012444
# CG iteration 0, residual: 5.498918
# CG iteration 10, residual: 0.049337
# CG iteration 20, residual: 0.096105
# CG iteration 30, residual: 0.056051
# CG iteration 40, residual: 0.066631
# CG iteration 50, residual: 0.021037
# CG iteration 60, residual: 0.014265
# CG iteration 70, residual: 0.014036
# CG iteration 80, residual: 0.008718
# CG iteration 90, residual: 0.025739
# CG iteration 0, residual: 5.309343
# CG iteration 10, residual: 0.106035
# CG iteration 20, residual: 0.079843
# CG iteration 30, residual: 0.035399
# CG iteration 40, residual: 0.096034
# CG iteration 50, residual: 0.052164
# CG iteration 60, residual: 0.036464
# CG iteration 70, residual: 0.059579
# CG iteration 80, residual: 0.011040
# CG iteration 90, residual: 0.015212
# CG iteration 0, residual: 5.095300
# CG iteration 10, residual: 0.083097
# CG iteration 20, residual: 0.053404
# CG iteration 30, residual: 0.040635
# CG iteration 40, residual: 0.036150
# CG iteration 50, residual: 0.034646
# CG iteration 60, residual: 0.017262
# CG iteration 70, residual: 0.017861
# CG iteration 80, residual: 0.013510
# CG iteration 90, residual: 0.015674
# CG iteration 0, residual: 4.867304
# CG iteration 10, residual: 0.123458
# CG iteration 20, residual: 0.058758
# CG iteration 30, residual: 0.056163
# CG iteration 40, residual: 0.076220
# CG iteration 50, residual: 0.074816
# CG iteration 60, residual: 0.023967
# CG iteration 70, residual: 0.017796
# CG iteration 80, residual: 0.009744
# CG iteration 90, residual: 0.003434
# CG iteration 0, residual: 4.636729
# CG iteration 10, residual: 0.101876
# CG iteration 20, residual: 0.070402
# CG iteration 30, residual: 0.124422
# CG iteration 40, residual: 0.068324
# CG iteration 50, residual: 0.016994
# CG iteration 60, residual: 0.020148
# CG iteration 70, residual: 0.019905
# CG iteration 80, residual: 0.023031
# CG iteration 90, residual: 0.014278
# CG iteration 0, residual: 4.415280
# CG iteration 10, residual: 0.144609
# CG iteration 20, residual: 0.049081
# CG iteration 30, residual: 0.143443
# CG iteration 40, residual: 0.017670
# CG iteration 50, residual: 0.018807
# CG iteration 60, residual: 0.009574
# CG iteration 70, residual: 0.005962
# CG iteration 80, residual: 0.007792
# CG iteration 90, residual: 0.004925
# CG iteration 0, residual: 4.214300
# CG iteration 10, residual: 0.139106
# CG iteration 20, residual: 0.056370
# CG iteration 30, residual: 0.053898
# CG iteration 40, residual: 0.029804
# CG iteration 50, residual: 0.022951
# CG iteration 60, residual: 0.020301
# CG iteration 70, residual: 0.017185
# CG iteration 80, residual: 0.029992
# CG iteration 90, residual: 0.007158
# CG iteration 0, residual: 4.043854
# CG iteration 10, residual: 0.139354
# CG iteration 20, residual: 0.092397
# CG iteration 30, residual: 0.063307
# CG iteration 40, residual: 0.036107
# CG iteration 50, residual: 0.035277
# CG iteration 60, residual: 0.003481
# CG iteration 70, residual: 0.010477
# CG iteration 80, residual: 0.004920
# CG iteration 90, residual: 0.007983
# CG iteration 0, residual: 3.911696
# CG iteration 10, residual: 0.141140
# CG iteration 20, residual: 0.109529
# CG iteration 30, residual: 0.057064
# CG iteration 40, residual: 0.025612
# CG iteration 50, residual: 0.016049
# CG iteration 60, residual: 0.008427
# CG iteration 70, residual: 0.006413
# CG iteration 80, residual: 0.012634
# CG iteration 90, residual: 0.002798
# CG iteration 0, residual: 3.822288
# CG iteration 10, residual: 0.106119
# CG iteration 20, residual: 0.067681
# CG iteration 30, residual: 0.023851
# CG iteration 40, residual: 0.026655
# CG iteration 50, residual: 0.013880
# CG iteration 60, residual: 0.005391
# CG iteration 70, residual: 0.003835
# CG iteration 80, residual: 0.006114
# CG iteration 90, residual: 0.001359
# CG iteration 0, residual: 3.776230
# CG iteration 10, residual: 0.107815
# CG iteration 20, residual: 0.055931
# CG iteration 30, residual: 0.021063
# CG iteration 40, residual: 0.005927
# CG iteration 50, residual: 0.011535
# CG iteration 60, residual: 0.002988
# CG iteration 70, residual: 0.003959
# CG iteration 80, residual: 0.002588
# CG iteration 90, residual: 0.005225
# CG iteration 0, residual: 3.770336
# CG iteration 10, residual: 0.168736
# CG iteration 20, residual: 0.057411
# CG iteration 30, residual: 0.017857
# CG iteration 40, residual: 0.017608
# CG iteration 50, residual: 0.011989
# CG iteration 60, residual: 0.007252
# CG iteration 70, residual: 0.001950
# CG iteration 80, residual: 0.002218
# CG iteration 90, residual: 0.007231
# CG iteration 0, residual: 3.798449
# CG iteration 10, residual: 0.270397
# CG iteration 20, residual: 0.044823
# CG iteration 30, residual: 0.011754
# CG iteration 40, residual: 0.020761
# CG iteration 50, residual: 0.012563
# CG iteration 60, residual: 0.004659
# CG iteration 70, residual: 0.006852
# CG iteration 80, residual: 0.007691
# CG iteration 90, residual: 0.001808
# CG iteration 0, residual: 3.852672
# CG iteration 10, residual: 0.148794
# CG iteration 20, residual: 0.058074
# CG iteration 30, residual: 0.013847
# CG iteration 40, residual: 0.037890
# CG iteration 50, residual: 0.004763
# CG iteration 60, residual: 0.005844
# CG iteration 70, residual: 0.006197
# CG iteration 80, residual: 0.002038
# CG iteration 90, residual: 0.005024
# CG iteration 0, residual: 3.924666
# CG iteration 10, residual: 0.084776
# CG iteration 20, residual: 0.053283
# CG iteration 30, residual: 0.020434
# CG iteration 40, residual: 0.015519
# CG iteration 50, residual: 0.008237
# CG iteration 60, residual: 0.014581
# CG iteration 70, residual: 0.003432
# CG iteration 80, residual: 0.011455
# CG iteration 90, residual: 0.003075
# CG iteration 0, residual: 4.006662
# CG iteration 10, residual: 0.096717
# CG iteration 20, residual: 0.044842
# CG iteration 30, residual: 0.045080
# CG iteration 40, residual: 0.013397
# CG iteration 50, residual: 0.007427
# CG iteration 60, residual: 0.006279
# CG iteration 70, residual: 0.002922
# CG iteration 80, residual: 0.008024
# CG iteration 90, residual: 0.005604
# CG iteration 0, residual: 4.092097
# CG iteration 10, residual: 0.138109
# CG iteration 20, residual: 0.023684
# CG iteration 30, residual: 0.020877
# CG iteration 40, residual: 0.014236
# CG iteration 50, residual: 0.014053
# CG iteration 60, residual: 0.012510
# CG iteration 70, residual: 0.005824
# CG iteration 80, residual: 0.005732
# CG iteration 90, residual: 0.002062
# CG iteration 0, residual: 4.175879
# CG iteration 10, residual: 0.113872
# CG iteration 20, residual: 0.051167
# CG iteration 30, residual: 0.039301
# CG iteration 40, residual: 0.012258
# CG iteration 50, residual: 0.032223
# CG iteration 60, residual: 0.004903
# CG iteration 70, residual: 0.007593
# CG iteration 80, residual: 0.005299
# CG iteration 90, residual: 0.004596
# CG iteration 0, residual: 4.254393
# CG iteration 10, residual: 0.076511
# CG iteration 20, residual: 0.127790
# CG iteration 30, residual: 0.040225
# CG iteration 40, residual: 0.018119
# CG iteration 50, residual: 0.014514
# CG iteration 60, residual: 0.006670
# CG iteration 70, residual: 0.008138
# CG iteration 80, residual: 0.010258
# CG iteration 90, residual: 0.006402
# CG iteration 0, residual: 4.325356
# CG iteration 10, residual: 0.106882
# CG iteration 20, residual: 0.113534
# CG iteration 30, residual: 0.022500
# CG iteration 40, residual: 0.018665
# CG iteration 50, residual: 0.042134
# CG iteration 60, residual: 0.014279
# CG iteration 70, residual: 0.004688
# CG iteration 80, residual: 0.007730
# CG iteration 90, residual: 0.006202
# CG iteration 0, residual: 4.387593
# CG iteration 10, residual: 0.110474
# CG iteration 20, residual: 0.084672
# CG iteration 30, residual: 0.037607
# CG iteration 40, residual: 0.041762
# CG iteration 50, residual: 0.012474
# CG iteration 60, residual: 0.013205
# CG iteration 70, residual: 0.009565
# CG iteration 80, residual: 0.010705
# CG iteration 90, residual: 0.002445
# CG iteration 0, residual: 4.440790
# CG iteration 10, residual: 0.131285
# CG iteration 20, residual: 0.066670
# CG iteration 30, residual: 0.031428
# CG iteration 40, residual: 0.029674
# CG iteration 50, residual: 0.023314
# CG iteration 60, residual: 0.026100
# CG iteration 70, residual: 0.012711
# CG iteration 80, residual: 0.019877
# CG iteration 90, residual: 0.002883
# CG iteration 0, residual: 4.485250
# CG iteration 10, residual: 0.162258
# CG iteration 20, residual: 0.027774
# CG iteration 30, residual: 0.037027
# CG iteration 40, residual: 0.045025
# CG iteration 50, residual: 0.028032
# CG iteration 60, residual: 0.018737
# CG iteration 70, residual: 0.011121
# CG iteration 80, residual: 0.019791
# CG iteration 90, residual: 0.009575
# CG iteration 0, residual: 4.521688
# CG iteration 10, residual: 0.156166
# CG iteration 20, residual: 0.059464
# CG iteration 30, residual: 0.049341
# CG iteration 40, residual: 0.048775
# CG iteration 50, residual: 0.056002
# CG iteration 60, residual: 0.030737
# CG iteration 70, residual: 0.014731
# CG iteration 80, residual: 0.008341
# CG iteration 90, residual: 0.003275
# CG iteration 0, residual: 4.551054
# CG iteration 10, residual: 0.147344
# CG iteration 20, residual: 0.073154
# CG iteration 30, residual: 0.024125
# CG iteration 40, residual: 0.033082
# CG iteration 50, residual: 0.026305
# CG iteration 60, residual: 0.015802
# CG iteration 70, residual: 0.021918
# CG iteration 80, residual: 0.011707
# CG iteration 90, residual: 0.004716
# CG iteration 0, residual: 4.574392
# CG iteration 10, residual: 0.114280
# CG iteration 20, residual: 0.111545
# CG iteration 30, residual: 0.069055
# CG iteration 40, residual: 0.041824
# CG iteration 50, residual: 0.022630
# CG iteration 60, residual: 0.010646
# CG iteration 70, residual: 0.015268
# CG iteration 80, residual: 0.014836
# CG iteration 90, residual: 0.013288
# CG iteration 0, residual: 4.592736
# CG iteration 10, residual: 0.076965
# CG iteration 20, residual: 0.111326
# CG iteration 30, residual: 0.052250
# CG iteration 40, residual: 0.023493
# CG iteration 50, residual: 0.031681
# CG iteration 60, residual: 0.018783
# ...
# CG iteration 60, residual: 0.097228
# CG iteration 70, residual: 0.032760
# CG iteration 80, residual: 0.046765
# CG iteration 90, residual: 0.048220
# CG iteration 0, residual: 8.047288
# CG iteration 10, residual: 0.110828
# CG iteration 20, residual: 0.102682
# CG iteration 30, residual: 0.086697
# CG iteration 40, residual: 0.120391
# CG iteration 50, residual: 0.127414
# CG iteration 60, residual: 0.110658
# CG iteration 70, residual: 0.044864
# CG iteration 80, residual: 0.078271
# CG iteration 90, residual: 0.075359
# CG iteration 0, residual: 8.048972
# CG iteration 10, residual: 0.183864
# CG iteration 20, residual: 0.129571
# CG iteration 30, residual: 0.076368
# CG iteration 40, residual: 0.230655
# CG iteration 50, residual: 0.049983
# CG iteration 60, residual: 0.170150
# CG iteration 70, residual: 0.053415
# CG iteration 80, residual: 0.099648
# CG iteration 90, residual: 0.075632
# CG iteration 0, residual: 8.050780
# CG iteration 10, residual: 0.244806
# CG iteration 20, residual: 0.134855
# CG iteration 30, residual: 0.088224
# CG iteration 40, residual: 0.095373
# CG iteration 50, residual: 0.090930
# CG iteration 60, residual: 0.056711
# CG iteration 70, residual: 0.050338
# CG iteration 80, residual: 0.048200
# CG iteration 90, residual: 0.023228
# CG iteration 0, residual: 8.052494
# CG iteration 10, residual: 0.300301
# CG iteration 20, residual: 0.191406
# CG iteration 30, residual: 0.052052
# CG iteration 40, residual: 0.109369
# CG iteration 50, residual: 0.090227
# CG iteration 60, residual: 0.058920
# CG iteration 70, residual: 0.034144
# CG iteration 80, residual: 0.041244
# CG iteration 90, residual: 0.034284
# CG iteration 0, residual: 8.053854
# CG iteration 10, residual: 0.323891
# CG iteration 20, residual: 0.130628
# CG iteration 30, residual: 0.059229
# CG iteration 40, residual: 0.054726
# CG iteration 50, residual: 0.111817
# CG iteration 60, residual: 0.043721
# CG iteration 70, residual: 0.064464
# CG iteration 80, residual: 0.019342
# CG iteration 90, residual: 0.031061
# CG iteration 0, residual: 8.054552
# CG iteration 10, residual: 0.317009
# CG iteration 20, residual: 0.075065
# CG iteration 30, residual: 0.063961
# CG iteration 40, residual: 0.061358
# CG iteration 50, residual: 0.033146
# CG iteration 60, residual: 0.027750
# CG iteration 70, residual: 0.028301
# CG iteration 80, residual: 0.014596
# CG iteration 90, residual: 0.032667
# CG iteration 0, residual: 8.054223
# CG iteration 10, residual: 0.281113
# CG iteration 20, residual: 0.110272
# CG iteration 30, residual: 0.109281
# CG iteration 40, residual: 0.026288
# CG iteration 50, residual: 0.036732
# CG iteration 60, residual: 0.019612
# CG iteration 70, residual: 0.013018
# CG iteration 80, residual: 0.032852
# CG iteration 90, residual: 0.011310
# CG iteration 0, residual: 8.052439
# CG iteration 10, residual: 0.179480
# CG iteration 20, residual: 0.077707
# CG iteration 30, residual: 0.082594
# CG iteration 40, residual: 0.049632
# CG iteration 50, residual: 0.020839
# CG iteration 60, residual: 0.040059
# CG iteration 70, residual: 0.013667
# CG iteration 80, residual: 0.063692
# CG iteration 90, residual: 0.006345
# CG iteration 0, residual: 8.048689
# CG iteration 10, residual: 0.152801
# CG iteration 20, residual: 0.088977
# CG iteration 30, residual: 0.035762
# CG iteration 40, residual: 0.043909
# CG iteration 50, residual: 0.014061
# CG iteration 60, residual: 0.026082
# CG iteration 70, residual: 0.010608
# CG iteration 80, residual: 0.044501
# CG iteration 90, residual: 0.013469
# CG iteration 0, residual: 8.042359
# CG iteration 10, residual: 0.199454
# CG iteration 20, residual: 0.112763
# CG iteration 30, residual: 0.028448
# CG iteration 40, residual: 0.011931
# CG iteration 50, residual: 0.037793
# CG iteration 60, residual: 0.010165
# CG iteration 70, residual: 0.022515
# CG iteration 80, residual: 0.019807
# CG iteration 90, residual: 0.024104
# CG iteration 0, residual: 8.032709
# CG iteration 10, residual: 0.177756
# CG iteration 20, residual: 0.103911
# CG iteration 30, residual: 0.014501
# CG iteration 40, residual: 0.024286
# CG iteration 50, residual: 0.023531
# CG iteration 60, residual: 0.025091
# CG iteration 70, residual: 0.025915
# CG iteration 80, residual: 0.050584
# CG iteration 90, residual: 0.018717
# CG iteration 0, residual: 8.018847
# CG iteration 10, residual: 0.139745
# CG iteration 20, residual: 0.126528
# CG iteration 30, residual: 0.018690
# CG iteration 40, residual: 0.041563
# CG iteration 50, residual: 0.052579
# CG iteration 60, residual: 0.032494
# CG iteration 70, residual: 0.036603
# CG iteration 80, residual: 0.017423
# CG iteration 90, residual: 0.047644
# CG iteration 0, residual: 7.999714
# CG iteration 10, residual: 0.263152
# CG iteration 20, residual: 0.089906
# CG iteration 30, residual: 0.027422
# CG iteration 40, residual: 0.043083
# CG iteration 50, residual: 0.034851
# CG iteration 60, residual: 0.020400
# CG iteration 70, residual: 0.032239
# CG iteration 80, residual: 0.028097
# CG iteration 90, residual: 0.039095
# CG iteration 0, residual: 7.974054
# CG iteration 10, residual: 0.140503
# CG iteration 20, residual: 0.147909
# CG iteration 30, residual: 0.061331
# CG iteration 40, residual: 0.047687
# CG iteration 50, residual: 0.044823
# CG iteration 60, residual: 0.048092
# CG iteration 70, residual: 0.044270
# CG iteration 80, residual: 0.029486
# CG iteration 90, residual: 0.051497
# CG iteration 0, residual: 7.940439
# CG iteration 10, residual: 0.202214
# CG iteration 20, residual: 0.133502
# CG iteration 30, residual: 0.060539
# CG iteration 40, residual: 0.082325
# CG iteration 50, residual: 0.071285
# CG iteration 60, residual: 0.017958
# CG iteration 70, residual: 0.040530
# CG iteration 80, residual: 0.024217
# CG iteration 90, residual: 0.062820
# CG iteration 0, residual: 7.897282
# CG iteration 10, residual: 0.258159
# CG iteration 20, residual: 0.125447
# CG iteration 30, residual: 0.043178
# CG iteration 40, residual: 0.098681
# CG iteration 50, residual: 0.063273
# CG iteration 60, residual: 0.050445
# CG iteration 70, residual: 0.105844
# CG iteration 80, residual: 0.098553
# CG iteration 90, residual: 0.069986
# CG iteration 0, residual: 7.842897
# CG iteration 10, residual: 0.281240
# CG iteration 20, residual: 0.083114
# CG iteration 30, residual: 0.050254
# CG iteration 40, residual: 0.055425
# CG iteration 50, residual: 0.062985
# CG iteration 60, residual: 0.062888
# CG iteration 70, residual: 0.033824
# CG iteration 80, residual: 0.051888
# CG iteration 90, residual: 0.038280
# CG iteration 0, residual: 7.775631
# CG iteration 10, residual: 0.294087
# CG iteration 20, residual: 0.071005
# CG iteration 30, residual: 0.049352
# CG iteration 40, residual: 0.095236
# CG iteration 50, residual: 0.022251
# CG iteration 60, residual: 0.055189
# CG iteration 70, residual: 0.044523
# CG iteration 80, residual: 0.061769
# CG iteration 90, residual: 0.086989
# CG iteration 0, residual: 7.694001
# CG iteration 10, residual: 0.251701
# CG iteration 20, residual: 0.070333
# CG iteration 30, residual: 0.029557
# CG iteration 40, residual: 0.081760
# CG iteration 50, residual: 0.024628
# CG iteration 60, residual: 0.053933
# CG iteration 70, residual: 0.026719
# CG iteration 80, residual: 0.042885
# CG iteration 90, residual: 0.043796
# CG iteration 0, residual: 7.596951
# CG iteration 10, residual: 0.274925
# CG iteration 20, residual: 0.157201
# CG iteration 30, residual: 0.042918
# CG iteration 40, residual: 0.103849
# CG iteration 50, residual: 0.077443
# CG iteration 60, residual: 0.017809
# CG iteration 70, residual: 0.048739
# CG iteration 80, residual: 0.029286
# CG iteration 90, residual: 0.031343
# CG iteration 0, residual: 7.484140
# CG iteration 10, residual: 0.332344
# CG iteration 20, residual: 0.185678
# CG iteration 30, residual: 0.038126
# CG iteration 40, residual: 0.014680
# CG iteration 50, residual: 0.055193
# CG iteration 60, residual: 0.021871
# CG iteration 70, residual: 0.028134
# CG iteration 80, residual: 0.023447
# CG iteration 90, residual: 0.046040
# CG iteration 0, residual: 7.356305
# CG iteration 10, residual: 0.137594
# CG iteration 20, residual: 0.131157
# CG iteration 30, residual: 0.024174
# CG iteration 40, residual: 0.013975
# CG iteration 50, residual: 0.062920
# CG iteration 60, residual: 0.062318
# CG iteration 70, residual: 0.040227
# CG iteration 80, residual: 0.056261
# CG iteration 90, residual: 0.042325
# CG iteration 0, residual: 7.215669
# CG iteration 10, residual: 0.124653
# CG iteration 20, residual: 0.031951
# CG iteration 30, residual: 0.038929
# CG iteration 40, residual: 0.014812
# CG iteration 50, residual: 0.038185
# CG iteration 60, residual: 0.021581
# CG iteration 70, residual: 0.058157
# CG iteration 80, residual: 0.033806
# CG iteration 90, residual: 0.076471
# CG iteration 0, residual: 7.066377
# CG iteration 10, residual: 0.191663
# CG iteration 20, residual: 0.144987
# CG iteration 30, residual: 0.048105
# CG iteration 40, residual: 0.040384
# CG iteration 50, residual: 0.010371
# CG iteration 60, residual: 0.031576
# CG iteration 70, residual: 0.008762
# CG iteration 80, residual: 0.038386
# CG iteration 90, residual: 0.041610
# CG iteration 0, residual: 6.914875
# CG iteration 10, residual: 0.180547
# CG iteration 20, residual: 0.140901
# CG iteration 30, residual: 0.037277
# CG iteration 40, residual: 0.012656
# CG iteration 50, residual: 0.024597
# CG iteration 60, residual: 0.013623
# CG iteration 70, residual: 0.015295
# CG iteration 80, residual: 0.041365
# CG iteration 90, residual: 0.010327
# CG iteration 0, residual: 6.770163
# CG iteration 10, residual: 0.218168
# CG iteration 20, residual: 0.092426
# CG iteration 30, residual: 0.023707
# CG iteration 40, residual: 0.044271
# CG iteration 50, residual: 0.014470
# CG iteration 60, residual: 0.032526
# CG iteration 70, residual: 0.008909
# CG iteration 80, residual: 0.041723
# CG iteration 90, residual: 0.019050
# CG iteration 0, residual: 6.643784
# CG iteration 10, residual: 0.306716
# CG iteration 20, residual: 0.110388
# CG iteration 30, residual: 0.023910
# CG iteration 40, residual: 0.033018
# CG iteration 50, residual: 0.005872
# CG iteration 60, residual: 0.011141
# CG iteration 70, residual: 0.029067
# CG iteration 80, residual: 0.025780
# CG iteration 90, residual: 0.019397
# CG iteration 0, residual: 6.549327
# CG iteration 10, residual: 0.334154
# CG iteration 20, residual: 0.099585
# CG iteration 30, residual: 0.010306
# CG iteration 40, residual: 0.017388
# CG iteration 50, residual: 0.014114
# CG iteration 60, residual: 0.033827
# CG iteration 70, residual: 0.011614
# CG iteration 80, residual: 0.027502
# CG iteration 90, residual: 0.020851
# CG iteration 0, residual: 6.501314
# CG iteration 10, residual: 0.227022
# CG iteration 20, residual: 0.126081
# CG iteration 30, residual: 0.025267
# CG iteration 40, residual: 0.017333
# CG iteration 50, residual: 0.008065
# CG iteration 60, residual: 0.018255
# CG iteration 70, residual: 0.017967
# CG iteration 80, residual: 0.011867
# CG iteration 90, residual: 0.020005
# CG iteration 0, residual: 6.513404
# CG iteration 10, residual: 0.167062
# CG iteration 20, residual: 0.108755
# CG iteration 30, residual: 0.029035
# CG iteration 40, residual: 0.029873
# CG iteration 50, residual: 0.007534
# CG iteration 60, residual: 0.008494
# CG iteration 70, residual: 0.007842
# CG iteration 80, residual: 0.023720
# CG iteration 90, residual: 0.027949
# CG iteration 0, residual: 6.596109
# CG iteration 10, residual: 0.167900
# CG iteration 20, residual: 0.118345
# CG iteration 30, residual: 0.018806
# CG iteration 40, residual: 0.011585
# CG iteration 50, residual: 0.017116
# CG iteration 60, residual: 0.022080
# CG iteration 70, residual: 0.015690
# CG iteration 80, residual: 0.009834
# CG iteration 90, residual: 0.006043
# CG iteration 0, residual: 6.754672
# CG iteration 10, residual: 0.212614
# CG iteration 20, residual: 0.208401
# CG iteration 30, residual: 0.066523
# CG iteration 40, residual: 0.051822
# CG iteration 50, residual: 0.023579
# CG iteration 60, residual: 0.006229
# CG iteration 70, residual: 0.006581
# CG iteration 80, residual: 0.010337
# CG iteration 90, residual: 0.008388
# CG iteration 0, residual: 6.987700
# CG iteration 10, residual: 0.234443
# CG iteration 20, residual: 0.117371
# CG iteration 30, residual: 0.043706
# CG iteration 40, residual: 0.019587
# CG iteration 50, residual: 0.018549
# CG iteration 60, residual: 0.007572
# CG iteration 70, residual: 0.012035
# CG iteration 80, residual: 0.029917
# CG iteration 90, residual: 0.005440
# CG iteration 0, residual: 7.287097
# CG iteration 10, residual: 0.240759
# CG iteration 20, residual: 0.038791
# CG iteration 30, residual: 0.028909
# CG iteration 40, residual: 0.016544
# CG iteration 50, residual: 0.007979
# CG iteration 60, residual: 0.009240
# CG iteration 70, residual: 0.004441
# CG iteration 80, residual: 0.028687
# CG iteration 90, residual: 0.003536
# CG iteration 0, residual: 7.639125
# CG iteration 10, residual: 0.273177
# CG iteration 20, residual: 0.077821
# CG iteration 30, residual: 0.025319
# CG iteration 40, residual: 0.024528
# CG iteration 50, residual: 0.008644
# CG iteration 60, residual: 0.004751
# CG iteration 70, residual: 0.015558
# CG iteration 80, residual: 0.020931
# CG iteration 90, residual: 0.008916
# CG iteration 0, residual: 8.026121
# CG iteration 10, residual: 0.204133
# CG iteration 20, residual: 0.034925
# CG iteration 30, residual: 0.037795
# CG iteration 40, residual: 0.013739
# CG iteration 50, residual: 0.007969
# CG iteration 60, residual: 0.011450
# CG iteration 70, residual: 0.016266
# CG iteration 80, residual: 0.007647
# CG iteration 90, residual: 0.004981
# CG iteration 0, residual: 8.428314
# CG iteration 10, residual: 0.225311
# CG iteration 20, residual: 0.035070
# CG iteration 30, residual: 0.015829
# CG iteration 40, residual: 0.019422
# CG iteration 50, residual: 0.015770
# CG iteration 60, residual: 0.026282
# CG iteration 70, residual: 0.013454
# CG iteration 80, residual: 0.022809
# CG iteration 90, residual: 0.017722
# CG iteration 0, residual: 8.825367
# CG iteration 10, residual: 0.154077
# CG iteration 20, residual: 0.053857
# CG iteration 30, residual: 0.031190
# CG iteration 40, residual: 0.030679
# CG iteration 50, residual: 0.012340
# CG iteration 60, residual: 0.015471
# CG iteration 70, residual: 0.008297
# CG iteration 80, residual: 0.030631
# CG iteration 90, residual: 0.017625
# CG iteration 0, residual: 9.197603
# CG iteration 10, residual: 0.200272
# CG iteration 20, residual: 0.091001
# CG iteration 30, residual: 0.037344
# CG iteration 40, residual: 0.058648
# CG iteration 50, residual: 0.070480
# CG iteration 60, residual: 0.012282
# CG iteration 70, residual: 0.020160
# CG iteration 80, residual: 0.023336
# CG iteration 90, residual: 0.011822
# CG iteration 0, residual: 9.526845
# CG iteration 10, residual: 0.099824
# CG iteration 20, residual: 0.086406
# CG iteration 30, residual: 0.022647
# CG iteration 40, residual: 0.039146
# CG iteration 50, residual: 0.049273
# CG iteration 60, residual: 0.026760
# CG iteration 70, residual: 0.029919
# CG iteration 80, residual: 0.019562
# CG iteration 90, residual: 0.022771
# CG iteration 0, residual: 9.797077
# CG iteration 10, residual: 0.172020
# CG iteration 20, residual: 0.060907
# CG iteration 30, residual: 0.074762
# CG iteration 40, residual: 0.070347
# CG iteration 50, residual: 0.021203
# CG iteration 60, residual: 0.044805
# CG iteration 70, residual: 0.013307
# CG iteration 80, residual: 0.026286
# CG iteration 90, residual: 0.004867
# CG iteration 0, residual: 9.994928
# CG iteration 10, residual: 0.426996
# CG iteration 20, residual: 0.156096
# CG iteration 30, residual: 0.065288
# CG iteration 40, residual: 0.085272
# CG iteration 50, residual: 0.021148
# CG iteration 60, residual: 0.055264
# CG iteration 70, residual: 0.008228
# CG iteration 80, residual: 0.029654
# CG iteration 90, residual: 0.012519
# CG iteration 0, residual: 10.110047
# CG iteration 10, residual: 0.783173
# CG iteration 20, residual: 0.292534
# CG iteration 30, residual: 0.063185
# CG iteration 40, residual: 0.045684
# CG iteration 50, residual: 0.024162
# CG iteration 60, residual: 0.022511
# CG iteration 70, residual: 0.016008
# CG iteration 80, residual: 0.050733
# CG iteration 90, residual: 0.013624
# CG iteration 0, residual: 10.135338
# CG iteration 10, residual: 1.151398
# CG iteration 20, residual: 0.371111
# CG iteration 30, residual: 0.111762
# CG iteration 40, residual: 0.045738
# CG iteration 50, residual: 0.043390
# CG iteration 60, residual: 0.018963
# CG iteration 70, residual: 0.016311
# CG iteration 80, residual: 0.041093
# CG iteration 90, residual: 0.044936
# n=6000, predict_time=11303.289s, RMSE=0.0292
